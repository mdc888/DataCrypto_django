# %% [markdown]
# <a href="https://colab.research.google.com/github/mdc888/DataCrypto_django/blob/main/Financial_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Financial Data Analysis

# %% [markdown]
# Financial Data Analysis with Python - a Deep Dive
# Installing required Libraries/Packages
# Install yfinance with:
#
# pip install yfinance
# (first: conda update anaconda)

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.4.4)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.8/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from yfinance) (4.9.2)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 KB 13.2 MB/s eta 0:00:00
# Collecting cryptography>=3.3.2
#   Downloading cryptography-39.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 69.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (2022.7.1)
# Collecting requests>=2.26
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 939.0 kB/s eta 0:00:00
# Collecting beautifulsoup4>=4.11.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from yfinance) (1.21.6)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib>=1.1->yfinance) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Installing collected packages: soupsieve, requests, html5lib, frozendict, cryptography, beautifulsoup4, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 cryptography-39.0.1 frozendict-2.3.5 html5lib-1.1 requests-2.28.2 soupsieve-2.4 yfinance-0.2.12

# %% [markdown]
# # Loading Financial Data from the Web

# %%
import pandas as pd
import yfinance as yf

# %%
start = "2021-10-01"
end = "2023-02-18"

# %%
symbol = "BA"

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-01  222.850006  226.720001  220.600006  226.000000  226.000000
# 2021-10-04  225.679993  227.970001  222.000000  223.789993  223.789993
# 2021-10-05  224.270004  226.449997  222.419998  224.419998  224.419998
# 2021-10-06  221.080002  225.070007  219.199997  224.990005  224.990005
# 2021-10-07  227.339996  229.000000  225.899994  226.479996  226.479996
# ...                ...         ...         ...         ...         ...
# 2023-02-13  213.600006  216.360001  211.500000  215.649994  215.649994
# 2023-02-14  214.020004  221.330002  213.149994  218.449997  218.449997
# 2023-02-15  217.160004  218.250000  214.600006  217.440002  217.440002
# 2023-02-16  215.000000  216.520004  212.169998  212.210007  212.210007
# 2023-02-17  211.210007  211.759995  207.619995  211.660004  211.660004
#
#               Volume
# Date
# 2021-10-01   9113600
# 2021-10-04   6946100
# 2021-10-05   5687300
# 2021-10-06   7157600
# 2021-10-07   7748500
# ...              ...
# 2023-02-13   5193300
# 2023-02-14  10033100
# 2023-02-15   4852400
# 2023-02-16   4388000
# 2023-02-17   4983600
#
# [348 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 348 entries, 2021-10-01 to 2023-02-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       348 non-null    float64
#  1   High       348 non-null    float64
#  2   Low        348 non-null    float64
#  3   Close      348 non-null    float64
#  4   Adj Close  348 non-null    float64
#  5   Volume     348 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 19.0 KB

# %%
symbol = ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %%
# Ticker Symbols: 

#     *  BA: Boeing (US Stock)
#     *  MSFT: Microsoft Corp (US Stock)
#     * ^DJI: Dow Jones Industrial Average (US Stock Index)
#     *  EURUSD=X: Exchange Rate for Currency Pair EUR/USD (Forex)
#     * GC=F: Gold Price (Precious Metal / Commodity)
#     * BTC-USD: Bitcoin in USD (Cryptocurrency)

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  6 of 6 completed
#              Adj Close                                                   \
#                     BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2021-10-01  226.000000  48116.941406  1.157448  1757.000000  285.178894
# 2021-10-02         NaN  47711.488281       NaN          NaN         NaN
# 2021-10-03         NaN  48199.953125       NaN          NaN         NaN
# 2021-10-04  223.789993  49112.902344  1.160726  1766.199951  279.270111
# 2021-10-05  224.419998  51514.812500  1.161845  1759.599976  284.843536
# ...                ...           ...       ...          ...         ...
# 2023-02-13  215.649994  21808.101562  1.067771  1851.900024  270.642120
# 2023-02-14  218.449997  22220.804688  1.073042  1854.000000  271.490021
# 2023-02-15  217.440002  24307.841797  1.073572  1834.199951  269.320007
# 2023-02-16  212.210007           NaN  1.069176  1842.000000  262.149994
# 2023-02-17  211.660004           NaN  1.066576  1851.300049  258.059998
#
#                                Close                                       \
#                     ^DJI          BA       BTC-USD  EURUSD=X         GC=F
# Date
# 2021-10-01  34326.460938  226.000000  48116.941406  1.157448  1757.000000
# 2021-10-02           NaN         NaN  47711.488281       NaN          NaN
# 2021-10-03           NaN         NaN  48199.953125       NaN          NaN
# 2021-10-04  34002.921875  223.789993  49112.902344  1.160726  1766.199951
# 2021-10-05  34314.671875  224.419998  51514.812500  1.161845  1759.599976
# ...                  ...         ...           ...       ...          ...
# 2023-02-13  34245.929688  215.649994  21808.101562  1.067771  1851.900024
# 2023-02-14  34089.269531  218.449997  22220.804688  1.073042  1854.000000
# 2023-02-15  34128.050781  217.440002  24307.841797  1.073572  1834.199951
# 2023-02-16  33696.851562  212.210007           NaN  1.069176  1842.000000
# 2023-02-17  33826.691406  211.660004           NaN  1.066576  1851.300049
#
#             ...      Open                                             Volume  \
#             ...  EURUSD=X         GC=F        MSFT          ^DJI          BA
# Date        ...
# 2021-10-01  ...  1.157421  1754.300049  282.119995  33930.699219   9113600.0
# 2021-10-02  ...       NaN          NaN         NaN           NaN         NaN
# 2021-10-03  ...       NaN          NaN         NaN           NaN         NaN
# 2021-10-04  ...  1.160726  1764.500000  287.399994  34312.960938   6946100.0
# 2021-10-05  ...  1.161656  1764.300049  284.049988  34035.250000   5687300.0
# ...         ...       ...          ...         ...           ...         ...
# 2023-02-13  ...  1.067771  1859.000000  267.640015  33887.390625   5193300.0
# 2023-02-14  ...  1.073042  1854.099976  272.670013  34194.089844  10033100.0
# 2023-02-15  ...  1.073572  1842.000000  268.320007  34008.628906   4852400.0
# 2023-02-16  ...  1.069176  1838.599976  264.019989  33992.089844   4388000.0
# 2023-02-17  ...  1.066576  1845.699951  259.390015  33677.011719   4983600.0
#
#
#                  BTC-USD EURUSD=X      GC=F        MSFT         ^DJI
# Date
# 2021-10-01  4.285064e+10      0.0    2220.0  30086300.0  427580000.0
# 2021-10-02  3.061435e+10      NaN       NaN         NaN          NaN
# 2021-10-03  2.663812e+10      NaN       NaN         NaN          NaN
# 2021-10-04  3.338317e+10      0.0     417.0  31350700.0  396860000.0
# 2021-10-05  3.587390e+10      0.0      98.0  24993000.0  311520000.0
# ...                  ...      ...       ...         ...          ...
# 2023-02-13  2.391874e+10      0.0     569.0  44630900.0  302600000.0
# 2023-02-14  2.679260e+10      0.0     656.0  37047900.0  288820000.0
# 2023-02-15  3.248331e+10      0.0     368.0  28962200.0  267530000.0
# 2023-02-16           NaN      0.0     222.0  29603600.0  317530000.0
# 2023-02-17           NaN      0.0  161154.0  29979600.0  302900000.0
#
# [505 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Freq: D
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        348 non-null    float64
#  1   (Adj Close, BTC-USD)   503 non-null    float64
#  2   (Adj Close, EURUSD=X)  361 non-null    float64
#  3   (Adj Close, GC=F)      350 non-null    float64
#  4   (Adj Close, MSFT)      348 non-null    float64
#  5   (Adj Close, ^DJI)      348 non-null    float64
#  6   (Close, BA)            348 non-null    float64
#  7   (Close, BTC-USD)       503 non-null    float64
#  8   (Close, EURUSD=X)      361 non-null    float64
#  9   (Close, GC=F)          350 non-null    float64
#  10  (Close, MSFT)          348 non-null    float64
#  11  (Close, ^DJI)          348 non-null    float64
#  12  (High, BA)             348 non-null    float64
#  13  (High, BTC-USD)        503 non-null    float64
#  14  (High, EURUSD=X)       361 non-null    float64
#  15  (High, GC=F)           350 non-null    float64
#  16  (High, MSFT)           348 non-null    float64
#  17  (High, ^DJI)           348 non-null    float64
#  18  (Low, BA)              348 non-null    float64
#  19  (Low, BTC-USD)         503 non-null    float64
#  20  (Low, EURUSD=X)        361 non-null    float64
#  21  (Low, GC=F)            350 non-null    float64
#  22  (Low, MSFT)            348 non-null    float64
#  23  (Low, ^DJI)            348 non-null    float64
#  24  (Open, BA)             348 non-null    float64
#  25  (Open, BTC-USD)        503 non-null    float64
#  26  (Open, EURUSD=X)       361 non-null    float64
#  27  (Open, GC=F)           350 non-null    float64
#  28  (Open, MSFT)           348 non-null    float64
#  29  (Open, ^DJI)           348 non-null    float64
#  30  (Volume, BA)           348 non-null    float64
#  31  (Volume, BTC-USD)      503 non-null    float64
#  32  (Volume, EURUSD=X)     361 non-null    float64
#  33  (Volume, GC=F)         350 non-null    float64
#  34  (Volume, MSFT)         348 non-null    float64
#  35  (Volume, ^DJI)         348 non-null    float64
# dtypes: float64(36)
# memory usage: 146.0 KB

# %%
df.to_csv("multi_assets.csv")

# %% [markdown]
# # Initial Inspection and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

# %%
df = pd.read_csv("multi_assets.csv", header = [0, 1], index_col = 0, parse_dates = [0])
df
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01  226.0000 48116.9414   1.1574 1757.0000 285.1789 34326.4609
# 2021-10-02       NaN 47711.4883      NaN       NaN      NaN        NaN
# 2021-10-03       NaN 48199.9531      NaN       NaN      NaN        NaN
# 2021-10-04  223.7900 49112.9023   1.1607 1766.2000 279.2701 34002.9219
# 2021-10-05  224.4200 51514.8125   1.1618 1759.6000 284.8435 34314.6719
# ...              ...        ...      ...       ...      ...        ...
# 2023-02-13  215.6500 21808.1016   1.0678 1851.9000 270.6421 34245.9297
# 2023-02-14  218.4500 22220.8047   1.0730 1854.0000 271.4900 34089.2695
# 2023-02-15  217.4400 24307.8418   1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16  212.2100        NaN   1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17  211.6600        NaN   1.0666 1851.3000 258.0600 33826.6914
#
#               Close                                ...     Open            \
#                  BA    BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F
# Date                                               ...
# 2021-10-01 226.0000 48116.9414   1.1574 1757.0000  ...   1.1574 1754.3000
# 2021-10-02      NaN 47711.4883      NaN       NaN  ...      NaN       NaN
# 2021-10-03      NaN 48199.9531      NaN       NaN  ...      NaN       NaN
# 2021-10-04 223.7900 49112.9023   1.1607 1766.2000  ...   1.1607 1764.5000
# 2021-10-05 224.4200 51514.8125   1.1618 1759.6000  ...   1.1617 1764.3000
# ...             ...        ...      ...       ...  ...      ...       ...
# 2023-02-13 215.6500 21808.1016   1.0678 1851.9000  ...   1.0678 1859.0000
# 2023-02-14 218.4500 22220.8047   1.0730 1854.0000  ...   1.0730 1854.1000
# 2023-02-15 217.4400 24307.8418   1.0736 1834.2000  ...   1.0736 1842.0000
# 2023-02-16 212.2100        NaN   1.0692 1842.0000  ...   1.0692 1838.6000
# 2023-02-17 211.6600        NaN   1.0666 1851.3000  ...   1.0666 1845.7000
#
#                                       Volume                            \
#                MSFT       ^DJI            BA          BTC-USD EURUSD=X
# Date
# 2021-10-01 282.1200 33930.6992  9113600.0000 42850641582.0000   0.0000
# 2021-10-02      NaN        NaN           NaN 30614346492.0000      NaN
# 2021-10-03      NaN        NaN           NaN 26638115879.0000      NaN
# 2021-10-04 287.4000 34312.9609  6946100.0000 33383173002.0000   0.0000
# 2021-10-05 284.0500 34035.2500  5687300.0000 35873904236.0000   0.0000
# ...             ...        ...           ...              ...      ...
# 2023-02-13 267.6400 33887.3906  5193300.0000 23918742607.0000   0.0000
# 2023-02-14 272.6700 34194.0898 10033100.0000 26792596581.0000   0.0000
# 2023-02-15 268.3200 34008.6289  4852400.0000 32483312909.0000   0.0000
# 2023-02-16 264.0200 33992.0898  4388000.0000              NaN   0.0000
# 2023-02-17 259.3900 33677.0117  4983600.0000              NaN   0.0000
#
#
#                   GC=F          MSFT           ^DJI
# Date
# 2021-10-01   2220.0000 30086300.0000 427580000.0000
# 2021-10-02         NaN           NaN            NaN
# 2021-10-03         NaN           NaN            NaN
# 2021-10-04    417.0000 31350700.0000 396860000.0000
# 2021-10-05     98.0000 24993000.0000 311520000.0000
# ...                ...           ...            ...
# 2023-02-13    569.0000 44630900.0000 302600000.0000
# 2023-02-14    656.0000 37047900.0000 288820000.0000
# 2023-02-15    368.0000 28962200.0000 267530000.0000
# 2023-02-16    222.0000 29603600.0000 317530000.0000
# 2023-02-17 161154.0000 29979600.0000 302900000.0000
#
# [505 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        348 non-null    float64
#  1   (Adj Close, BTC-USD)   503 non-null    float64
#  2   (Adj Close, EURUSD=X)  361 non-null    float64
#  3   (Adj Close, GC=F)      350 non-null    float64
#  4   (Adj Close, MSFT)      348 non-null    float64
#  5   (Adj Close, ^DJI)      348 non-null    float64
#  6   (Close, BA)            348 non-null    float64
#  7   (Close, BTC-USD)       503 non-null    float64
#  8   (Close, EURUSD=X)      361 non-null    float64
#  9   (Close, GC=F)          350 non-null    float64
#  10  (Close, MSFT)          348 non-null    float64
#  11  (Close, ^DJI)          348 non-null    float64
#  12  (High, BA)             348 non-null    float64
#  13  (High, BTC-USD)        503 non-null    float64
#  14  (High, EURUSD=X)       361 non-null    float64
#  15  (High, GC=F)           350 non-null    float64
#  16  (High, MSFT)           348 non-null    float64
#  17  (High, ^DJI)           348 non-null    float64
#  18  (Low, BA)              348 non-null    float64
#  19  (Low, BTC-USD)         503 non-null    float64
#  20  (Low, EURUSD=X)        361 non-null    float64
#  21  (Low, GC=F)            350 non-null    float64
#  22  (Low, MSFT)            348 non-null    float64
#  23  (Low, ^DJI)            348 non-null    float64
#  24  (Open, BA)             348 non-null    float64
#  25  (Open, BTC-USD)        503 non-null    float64
#  26  (Open, EURUSD=X)       361 non-null    float64
#  27  (Open, GC=F)           350 non-null    float64
#  28  (Open, MSFT)           348 non-null    float64
#  29  (Open, ^DJI)           348 non-null    float64
#  30  (Volume, BA)           348 non-null    float64
#  31  (Volume, BTC-USD)      503 non-null    float64
#  32  (Volume, EURUSD=X)     361 non-null    float64
#  33  (Volume, GC=F)         350 non-null    float64
#  34  (Volume, MSFT)         348 non-null    float64
#  35  (Volume, ^DJI)         348 non-null    float64
# dtypes: float64(36)
# memory usage: 146.0 KB

# %%
df.Close # outer index level
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
df.Close.BA # one column (1)
# Out:
# Date
# 2021-10-01   226.0000
# 2021-10-02        NaN
# 2021-10-03        NaN
# 2021-10-04   223.7900
# 2021-10-05   224.4200
#                ...
# 2023-02-13   215.6500
# 2023-02-14   218.4500
# 2023-02-15   217.4400
# 2023-02-16   212.2100
# 2023-02-17   211.6600
# Name: BA, Length: 505, dtype: float64

# %%
df.loc[:, ("Close", "BA")] # one column (2)
# Out:
# Date
# 2021-10-01   226.0000
# 2021-10-02        NaN
# 2021-10-03        NaN
# 2021-10-04   223.7900
# 2021-10-05   224.4200
#                ...
# 2023-02-13   215.6500
# 2023-02-14   218.4500
# 2023-02-15   217.4400
# 2023-02-16   212.2100
# 2023-02-17   211.6600
# Name: (Close, BA), Length: 505, dtype: float64

# %%
df.loc["2022-01-07"] # one row
# Out:
# Adj Close  BA                 215.5000
#            BTC-USD          41557.9023
#            EURUSD=X             1.1297
#            GC=F              1797.0000
#            MSFT               310.3474
#            ^DJI             36231.6602
# Close      BA                 215.5000
#            BTC-USD          41557.9023
#            EURUSD=X             1.1297
#            GC=F              1797.0000
#            MSFT               314.0400
#            ^DJI             36231.6602
# High       BA                 218.3200
#            BTC-USD          43153.5703
#            EURUSD=X             1.1360
#            GC=F              1797.0000
#            MSFT               316.5000
#            ^DJI             36382.8398
# Low        BA                 212.3800
#            BTC-USD          41077.4453
#            EURUSD=X             1.1291
#            GC=F              1784.4000
#            MSFT               310.0900
#            ^DJI             36111.5312
# Open       BA                 212.9800
#            BTC-USD          43153.5703
#            EURUSD=X             1.1296
#            GC=F              1791.8000
#            MSFT               314.1500
#            ^DJI             36249.5898
# Volume     BA             9526400.0000
#            BTC-USD    84196607520.0000
#            EURUSD=X             0.0000
#            GC=F                17.0000
#            MSFT          32720000.0000
#            ^DJI         356110000.0000
# Name: 2022-01-07 00:00:00, dtype: float64

# %%
df.loc["2022"] # one year
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2022-01-01       NaN 47686.8125      NaN       NaN      NaN        NaN
# 2022-01-02       NaN 47345.2188      NaN       NaN      NaN        NaN
# 2022-01-03  207.8600 46458.1172   1.1373 1799.4000 330.8139 36585.0586
# 2022-01-04  213.6300 45897.5742   1.1302 1814.0000 325.1414 36799.6484
# 2022-01-05  213.0700 43569.0039   1.1284 1824.6000 312.6599 36407.1094
# ...              ...        ...      ...       ...      ...        ...
# 2022-12-27  189.4000 16717.1738   1.0640 1814.8000 236.3680 33241.5586
# 2022-12-28  188.3800 16552.5723   1.0637 1807.9000 233.9440 32875.7109
# 2022-12-29  188.9100 16642.3418   1.0629 1819.5000 240.4078 33220.8008
# 2022-12-30  190.4900 16602.5859   1.0661 1819.7000 239.2208 33147.2500
# 2022-12-31       NaN 16547.4961      NaN       NaN      NaN        NaN
#
#               Close                                ...     Open            \
#                  BA    BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F
# Date                                               ...
# 2022-01-01      NaN 47686.8125      NaN       NaN  ...      NaN       NaN
# 2022-01-02      NaN 47345.2188      NaN       NaN  ...      NaN       NaN
# 2022-01-03 207.8600 46458.1172   1.1373 1799.4000  ...   1.1374 1830.1000
# 2022-01-04 213.6300 45897.5742   1.1302 1814.0000  ...   1.1302 1800.5000
# 2022-01-05 213.0700 43569.0039   1.1284 1824.6000  ...   1.1285 1813.1000
# ...             ...        ...      ...       ...  ...      ...       ...
# 2022-12-27 189.4000 16717.1738   1.0640 1814.8000  ...   1.0640 1803.4000
# 2022-12-28 188.3800 16552.5723   1.0637 1807.9000  ...   1.0637 1803.2000
# 2022-12-29 188.9100 16642.3418   1.0629 1819.5000  ...   1.0629 1805.8000
# 2022-12-30 190.4900 16602.5859   1.0661 1819.7000  ...   1.0661 1817.0000
# 2022-12-31      NaN 16547.4961      NaN       NaN  ...      NaN       NaN
#
#                                       Volume                            \
#                MSFT       ^DJI            BA          BTC-USD EURUSD=X
# Date
# 2022-01-01      NaN        NaN           NaN 24582667004.0000      NaN
# 2022-01-02      NaN        NaN           NaN 27951569547.0000      NaN
# 2022-01-03 335.3500 36321.5898  9060200.0000 33071628362.0000   0.0000
# 2022-01-04 334.8300 36636.0000 11414600.0000 42494677905.0000   0.0000
# 2022-01-05 325.8600 36722.6016 11564700.0000 36851084859.0000   0.0000
# ...             ...        ...           ...              ...      ...
# 2022-12-27 238.7000 33224.2305  5014800.0000 15748580239.0000   0.0000
# 2022-12-28 236.8900 33264.7617  4426300.0000 17005713920.0000   0.0000
# 2022-12-29 235.6500 33021.4297  4518900.0000 14472237479.0000   0.0000
# 2022-12-30 238.2100 33121.6094  4005100.0000 15929162910.0000   0.0000
# 2022-12-31      NaN        NaN           NaN 11239186456.0000      NaN
#
#
#                GC=F          MSFT           ^DJI
# Date
# 2022-01-01      NaN           NaN            NaN
# 2022-01-02      NaN           NaN            NaN
# 2022-01-03 116.0000 28865100.0000 347930000.0000
# 2022-01-04  38.0000 32674300.0000 435080000.0000
# 2022-01-05   8.0000 40054300.0000 462040000.0000
# ...             ...           ...            ...
# 2022-12-27  69.0000 16688600.0000 246010000.0000
# 2022-12-28 434.0000 17457100.0000 252260000.0000
# 2022-12-29 277.0000 19770700.0000 243060000.0000
# 2022-12-30  95.0000 21930800.0000 295500000.0000
# 2022-12-31      NaN           NaN            NaN
#
# [365 rows x 36 columns]

# %%
df.loc["2022-06":, ("Close", "BA")] # one month for one column
# Out:
# Date
# 2022-06-01   130.6500
# 2022-06-02   140.5000
# 2022-06-03   139.2500
# 2022-06-04        NaN
# 2022-06-05        NaN
#                ...
# 2023-02-13   215.6500
# 2023-02-14   218.4500
# 2023-02-15   217.4400
# 2023-02-16   212.2100
# 2023-02-17   211.6600
# Name: (Close, BA), Length: 262, dtype: float64

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns") # swap outer and inner index
df
# Out:
#                   BA                                                    \
#            Adj Close    Close     High      Low     Open        Volume
# Date
# 2021-10-01  226.0000 226.0000 226.7200 220.6000 222.8500  9113600.0000
# 2021-10-02       NaN      NaN      NaN      NaN      NaN           NaN
# 2021-10-03       NaN      NaN      NaN      NaN      NaN           NaN
# 2021-10-04  223.7900 223.7900 227.9700 222.0000 225.6800  6946100.0000
# 2021-10-05  224.4200 224.4200 226.4500 222.4200 224.2700  5687300.0000
# ...              ...      ...      ...      ...      ...           ...
# 2023-02-13  215.6500 215.6500 216.3600 211.5000 213.6000  5193300.0000
# 2023-02-14  218.4500 218.4500 221.3300 213.1500 214.0200 10033100.0000
# 2023-02-15  217.4400 217.4400 218.2500 214.6000 217.1600  4852400.0000
# 2023-02-16  212.2100 212.2100 216.5200 212.1700 215.0000  4388000.0000
# 2023-02-17  211.6600 211.6600 211.7600 207.6200 211.2100  4983600.0000
#
#               BTC-USD                                   ...     MSFT           \
#             Adj Close      Close       High        Low  ...     High      Low
# Date                                                    ...
# 2021-10-01 48116.9414 48116.9414 48436.0117 43320.0234  ... 289.9800 281.2900
# 2021-10-02 47711.4883 47711.4883 48282.0625 47465.4961  ...      NaN      NaN
# 2021-10-03 48199.9531 48199.9531 49130.6914 47157.2891  ...      NaN      NaN
# 2021-10-04 49112.9023 49112.9023 49456.7773 47045.0039  ... 287.7500 280.2500
# 2021-10-05 51514.8125 51514.8125 51839.9844 49072.8398  ... 290.4000 284.0500
# ...               ...        ...        ...        ...  ...      ...      ...
# 2023-02-13 21808.1016 21808.1016 21898.4141 21460.0879  ... 274.6000 267.1500
# 2023-02-14 22220.8047 22220.8047 22293.1406 21632.3945  ... 274.9700 269.2800
# 2023-02-15 24307.8418 24307.8418 24307.8418 22082.7695  ... 270.7300 266.1800
# 2023-02-16        NaN        NaN        NaN        NaN  ... 266.7400 261.9000
# 2023-02-17        NaN        NaN        NaN        NaN  ... 260.0900 256.0000
#
#                                         ^DJI                                   \
#                Open        Volume  Adj Close      Close       High        Low
# Date
# 2021-10-01 282.1200 30086300.0000 34326.4609 34326.4609 34490.5586 33785.5391
# 2021-10-02      NaN           NaN        NaN        NaN        NaN        NaN
# 2021-10-03      NaN           NaN        NaN        NaN        NaN        NaN
# 2021-10-04 287.4000 31350700.0000 34002.9219 34002.9219 34410.2812 33821.5781
# 2021-10-05 284.0500 24993000.0000 34314.6719 34314.6719 34490.9492 34035.2500
# ...             ...           ...        ...        ...        ...        ...
# 2023-02-13 267.6400 44630900.0000 34245.9297 34245.9297 34249.6016 33887.3906
# 2023-02-14 272.6700 37047900.0000 34089.2695 34089.2695 34331.4688 33827.4492
# 2023-02-15 268.3200 28962200.0000 34128.0508 34128.0508 34130.4883 33833.1016
# 2023-02-16 264.0200 29603600.0000 33696.8516 33696.8516 34041.1602 33686.5898
# 2023-02-17 259.3900 29979600.0000 33826.6914 33826.6914 33846.6406 33517.7305
#
#
#                  Open         Volume
# Date
# 2021-10-01 33930.6992 427580000.0000
# 2021-10-02        NaN            NaN
# 2021-10-03        NaN            NaN
# 2021-10-04 34312.9609 396860000.0000
# 2021-10-05 34035.2500 311520000.0000
# ...               ...            ...
# 2023-02-13 33887.3906 302600000.0000
# 2023-02-14 34194.0898 288820000.0000
# 2023-02-15 34008.6289 267530000.0000
# 2023-02-16 33992.0898 317530000.0000
# 2023-02-17 33677.0117 302900000.0000
#
# [505 rows x 36 columns]

# %%
df["EURUSD=X"]
# Out:
#             Adj Close  Close   High    Low   Open  Volume
# Date
# 2021-10-01     1.1574 1.1574 1.1609 1.1564 1.1574  0.0000
# 2021-10-02        NaN    NaN    NaN    NaN    NaN     NaN
# 2021-10-03        NaN    NaN    NaN    NaN    NaN     NaN
# 2021-10-04     1.1607 1.1607 1.1640 1.1589 1.1607  0.0000
# 2021-10-05     1.1618 1.1618 1.1623 1.1583 1.1617  0.0000
# ...               ...    ...    ...    ...    ...     ...
# 2023-02-13     1.0678 1.0678 1.0725 1.0657 1.0678  0.0000
# 2023-02-14     1.0730 1.0730 1.0798 1.0710 1.0730  0.0000
# 2023-02-15     1.0736 1.0736 1.0745 1.0666 1.0736  0.0000
# 2023-02-16     1.0692 1.0692 1.0722 1.0656 1.0692  0.0000
# 2023-02-17     1.0666 1.0666 1.0681 1.0614 1.0666  0.0000
#
# [505 rows x 6 columns]

# %%
df["BTC-USD"]
# Out:
#             Adj Close      Close       High        Low       Open  \
# Date
# 2021-10-01 48116.9414 48116.9414 48436.0117 43320.0234 43816.7422
# 2021-10-02 47711.4883 47711.4883 48282.0625 47465.4961 48137.4688
# 2021-10-03 48199.9531 48199.9531 49130.6914 47157.2891 47680.0273
# 2021-10-04 49112.9023 49112.9023 49456.7773 47045.0039 48208.9062
# 2021-10-05 51514.8125 51514.8125 51839.9844 49072.8398 49174.9609
# ...               ...        ...        ...        ...        ...
# 2023-02-13 21808.1016 21808.1016 21898.4141 21460.0879 21787.0000
# 2023-02-14 22220.8047 22220.8047 22293.1406 21632.3945 21801.8223
# 2023-02-15 24307.8418 24307.8418 24307.8418 22082.7695 22220.5859
# 2023-02-16        NaN        NaN        NaN        NaN        NaN
# 2023-02-17        NaN        NaN        NaN        NaN        NaN
#
#                      Volume
# Date
# 2021-10-01 42850641582.0000
# 2021-10-02 30614346492.0000
# 2021-10-03 26638115879.0000
# 2021-10-04 33383173002.0000
# 2021-10-05 35873904236.0000
# ...                     ...
# 2023-02-13 23918742607.0000
# 2023-02-14 26792596581.0000
# 2023-02-15 32483312909.0000
# 2023-02-16              NaN
# 2023-02-17              NaN
#
# [505 rows x 6 columns]

# %%
df = df.swaplevel(axis = "columns").sort_index(axis = "columns") # swap outer and inner index
df
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01  226.0000 48116.9414   1.1574 1757.0000 285.1789 34326.4609
# 2021-10-02       NaN 47711.4883      NaN       NaN      NaN        NaN
# 2021-10-03       NaN 48199.9531      NaN       NaN      NaN        NaN
# 2021-10-04  223.7900 49112.9023   1.1607 1766.2000 279.2701 34002.9219
# 2021-10-05  224.4200 51514.8125   1.1618 1759.6000 284.8435 34314.6719
# ...              ...        ...      ...       ...      ...        ...
# 2023-02-13  215.6500 21808.1016   1.0678 1851.9000 270.6421 34245.9297
# 2023-02-14  218.4500 22220.8047   1.0730 1854.0000 271.4900 34089.2695
# 2023-02-15  217.4400 24307.8418   1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16  212.2100        NaN   1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17  211.6600        NaN   1.0666 1851.3000 258.0600 33826.6914
#
#               Close                                ...     Open            \
#                  BA    BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F
# Date                                               ...
# 2021-10-01 226.0000 48116.9414   1.1574 1757.0000  ...   1.1574 1754.3000
# 2021-10-02      NaN 47711.4883      NaN       NaN  ...      NaN       NaN
# 2021-10-03      NaN 48199.9531      NaN       NaN  ...      NaN       NaN
# 2021-10-04 223.7900 49112.9023   1.1607 1766.2000  ...   1.1607 1764.5000
# 2021-10-05 224.4200 51514.8125   1.1618 1759.6000  ...   1.1617 1764.3000
# ...             ...        ...      ...       ...  ...      ...       ...
# 2023-02-13 215.6500 21808.1016   1.0678 1851.9000  ...   1.0678 1859.0000
# 2023-02-14 218.4500 22220.8047   1.0730 1854.0000  ...   1.0730 1854.1000
# 2023-02-15 217.4400 24307.8418   1.0736 1834.2000  ...   1.0736 1842.0000
# 2023-02-16 212.2100        NaN   1.0692 1842.0000  ...   1.0692 1838.6000
# 2023-02-17 211.6600        NaN   1.0666 1851.3000  ...   1.0666 1845.7000
#
#                                       Volume                            \
#                MSFT       ^DJI            BA          BTC-USD EURUSD=X
# Date
# 2021-10-01 282.1200 33930.6992  9113600.0000 42850641582.0000   0.0000
# 2021-10-02      NaN        NaN           NaN 30614346492.0000      NaN
# 2021-10-03      NaN        NaN           NaN 26638115879.0000      NaN
# 2021-10-04 287.4000 34312.9609  6946100.0000 33383173002.0000   0.0000
# 2021-10-05 284.0500 34035.2500  5687300.0000 35873904236.0000   0.0000
# ...             ...        ...           ...              ...      ...
# 2023-02-13 267.6400 33887.3906  5193300.0000 23918742607.0000   0.0000
# 2023-02-14 272.6700 34194.0898 10033100.0000 26792596581.0000   0.0000
# 2023-02-15 268.3200 34008.6289  4852400.0000 32483312909.0000   0.0000
# 2023-02-16 264.0200 33992.0898  4388000.0000              NaN   0.0000
# 2023-02-17 259.3900 33677.0117  4983600.0000              NaN   0.0000
#
#
#                   GC=F          MSFT           ^DJI
# Date
# 2021-10-01   2220.0000 30086300.0000 427580000.0000
# 2021-10-02         NaN           NaN            NaN
# 2021-10-03         NaN           NaN            NaN
# 2021-10-04    417.0000 31350700.0000 396860000.0000
# 2021-10-05     98.0000 24993000.0000 311520000.0000
# ...                ...           ...            ...
# 2023-02-13    569.0000 44630900.0000 302600000.0000
# 2023-02-14    656.0000 37047900.0000 288820000.0000
# 2023-02-15    368.0000 28962200.0000 267530000.0000
# 2023-02-16    222.0000 29603600.0000 317530000.0000
# 2023-02-17 161154.0000 29979600.0000 302900000.0000
#
# [505 rows x 36 columns]

# %%
close = df.Close.copy() # select daily close prices only
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
close.describe()
# Out:
#             BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# count 348.0000   503.0000  361.0000  350.0000 348.0000   348.0000
# mean  178.6868 32609.1253    1.0724 1807.7694 277.0683 33462.8575
# std    31.2210 14445.5740    0.0552   84.5044  33.0166  1807.1189
# min   115.8600 15787.2842    0.9596 1623.3000 214.2500 28725.5098
# 25%   149.6500 20127.3584    1.0258 1757.7500 248.1200 32240.1294
# 50%   181.4800 28720.2715    1.0716 1804.6000 272.4600 33711.0547
# 75%   207.8525 42996.3281    1.1284 1862.8750 301.2800 34740.1064
# max   233.0900 67566.8281    1.1684 2040.1000 343.1100 36799.6484

# %%
close.BA.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
# Take Home: Absolute Prices are absolutely meaningless/useless (in most cases) 

# * Prices that are on a different scale are hard to compare
# * A higher Price does not imply a higher value or a better performance

# %% [markdown]
# # Normalizing Financial Time Series to a Base Value (100)
# -> all instruments start at the very same Level (Base Value)

# %%
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
close.iloc[0,0] # first price BA

# %%
close.BA.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2021-10-01   100.0000
# 2021-10-02        NaN
# 2021-10-03        NaN
# 2021-10-04    99.0221
# 2021-10-05    99.3009
#                ...
# 2023-02-13    95.4204
# 2023-02-14    96.6593
# 2023-02-15    96.2124
# 2023-02-16    93.8982
# 2023-02-17    93.6549
# Name: BA, Length: 505, dtype: float64

# %%
close.iloc[0] # first Price all tickers
# Out:
# BA           226.0000
# BTC-USD    48116.9414
# EURUSD=X       1.1574
# GC=F        1757.0000
# MSFT         289.1000
# ^DJI       34326.4609
# Name: 2021-10-01 00:00:00, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                  BA  BTC-USD  EURUSD=X     GC=F     MSFT     ^DJI
# Date
# 2021-10-01 100.0000 100.0000  100.0000 100.0000 100.0000 100.0000
# 2021-10-02      NaN  99.1574       NaN      NaN      NaN      NaN
# 2021-10-03      NaN 100.1725       NaN      NaN      NaN      NaN
# 2021-10-04  99.0221 102.0699  100.2832 100.5236  97.9280  99.0575
# 2021-10-05  99.3009 107.0617  100.3799 100.1480  99.8824  99.9657
# ...             ...      ...       ...      ...      ...      ...
# 2023-02-13  95.4204  45.3231   92.2523 105.4013  93.8499  99.7654
# 2023-02-14  96.6593  46.1808   92.7076 105.5208  94.1439  99.3090
# 2023-02-15  96.2124  50.5183   92.7534 104.3939  93.1581  99.4220
# 2023-02-16  93.8982      NaN   92.3736 104.8378  90.6780  98.1658
# 2023-02-17  93.6549      NaN   92.1489 105.3671  89.2632  98.5441
#
# [505 rows x 6 columns]

# %%
norm.dropna().plot(figsize = (15, 8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# Take Home: Normalized Prices help to compare Financial Instruments...
# ...but they are limited when it comes to measuring/comparing Performance in more detail.

# %%
close.to_csv("close.csv")

# %% [markdown]
# # Coding Challenge #1

# %% [markdown]
# Coding Challenge #1
#
# 1.Load Stock Price Data for General Electric (GE) and another ticker symbol of your choice from 2015-01-02 until 2020-12-31.
# Go to https://finance.yahoo.com/ and get the right ticker symbol. For instruments traded outside the US, you have to add a country/exchange suffix.
# Check the suffix list here https://help.yahoo.com/kb/exchanges-data-providers-yahoo-finance-sln2310.html As an example, the suffix for the National Indian Stock Exchange is .NS -> Ticker Symbol for Reliance is Reliance.NS
# 2.Select Close prices only and create a price chart for GE.
# 3.Normalize the stock prices for GE and the Ticker Symbol of your choice (Base Value: 1) and visualize! What´s the final normalized price for GE on 2020-12-30?
# You can find the solution for the Coding Challenges at the end of this notebook.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

# %%
start = "2020-01-02"
end = "2023-02-18"
symbol = ["GE", "Reliance.NS"]

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  2 of 2 completed
#            Adj Close               Close                High              \
#                   GE RELIANCE.NS      GE RELIANCE.NS      GE RELIANCE.NS
# Date
# 2020-01-02   73.5781   1505.8021 74.5043   1520.8835 74.6917   1526.4805
# 2020-01-03   73.8248   1507.6165 74.7541   1522.7162 74.9415   1527.1740
# 2020-01-06   74.8733   1472.6514 75.8158   1487.4009 76.2529   1513.5530
# 2020-01-07   74.3182   1495.3076 75.2537   1510.2841 76.4403   1520.0911
# 2020-01-08   73.6398   1484.0775 74.5667   1498.9415 75.2537   1520.0415
# ...              ...         ...     ...         ...     ...         ...
# 2023-02-13   82.6800   2323.3501 82.6800   2323.3501 82.9200   2350.0000
# 2023-02-14   83.5400   2378.1001 83.5400   2378.1001 83.8100   2381.8999
# 2023-02-15   84.7700   2431.9500 84.7700   2431.9500 84.7900   2437.2000
# 2023-02-16   84.0500   2430.0500 84.0500   2430.0500 84.5400   2463.8000
# 2023-02-17   83.0400   2440.2000 83.0400   2440.2000 83.8200   2447.5000
#
#                Low                Open                    Volume
#                 GE RELIANCE.NS      GE RELIANCE.NS            GE   RELIANCE.NS
# Date
# 2020-01-02 70.1327   1497.8024 70.1327   1497.8024 13998416.0000  8173308.0000
# 2020-01-03 72.0062   1508.6991 72.2561   1518.6051 13752464.0000  9684434.0000
# 2020-01-06 73.9422   1483.9338 73.9422   1505.7272 17925786.0000 11315596.0000
# 2020-01-07 74.4418   1499.2882 75.8782   1504.7366 11301510.0000  7699489.0000
# 2020-01-08 74.1296   1495.8212 74.8790   1500.7742  8871325.0000  7406104.0000
# ...            ...         ...     ...         ...           ...           ...
# 2023-02-13 81.0800   2313.5500 81.2000   2340.2000  4081600.0000  4777674.0000
# 2023-02-14 81.9600   2323.6499 82.1300   2329.9500  5368500.0000  6609564.0000
# 2023-02-15 82.4400   2373.0000 82.6100   2376.0000  5831400.0000 15461902.0000
# 2023-02-16 82.9800   2425.0500 83.6100   2449.4500  4505900.0000  7967558.0000
# 2023-02-17 82.2300   2410.6001 83.5900   2420.0000  4424200.0000  5450092.0000
#
# [813 rows x 12 columns]

# %%
close = df.Close.copy()
close
# Out:
#                 GE  RELIANCE.NS
# Date
# 2020-01-02 74.5043    1520.8835
# 2020-01-03 74.7541    1522.7162
# 2020-01-06 75.8158    1487.4009
# 2020-01-07 75.2537    1510.2841
# 2020-01-08 74.5667    1498.9415
# ...            ...          ...
# 2023-02-13 82.6800    2323.3501
# 2023-02-14 83.5400    2378.1001
# 2023-02-15 84.7700    2431.9500
# 2023-02-16 84.0500    2430.0500
# 2023-02-17 83.0400    2440.2000
#
# [813 rows x 2 columns]

# %%
close.GE.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
norm = close.div(close.iloc[0]).mul(1)
norm
# Out:
#                GE  RELIANCE.NS
# Date
# 2020-01-02 1.0000       1.0000
# 2020-01-03 1.0034       1.0012
# 2020-01-06 1.0176       0.9780
# 2020-01-07 1.0101       0.9930
# 2020-01-08 1.0008       0.9856
# ...           ...          ...
# 2023-02-13 1.1097       1.5276
# 2023-02-14 1.1213       1.5636
# 2023-02-15 1.1378       1.5990
# 2023-02-16 1.1281       1.5978
# 2023-02-17 1.1146       1.6045
#
# [813 rows x 2 columns]

# %%
# -> The final normalized Price is 0.4445.

norm.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# # Price Changes and Financial Returns
# More meaningful/useful than Prices: Price changes

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
msft = close.MSFT.dropna().to_frame().copy()

# %%
msft
# Out:
#                MSFT
# Date
# 2021-10-01 289.1000
# 2021-10-04 283.1100
# 2021-10-05 288.7600
# 2021-10-06 293.1100
# 2021-10-07 294.8500
# ...             ...
# 2023-02-13 271.3200
# 2023-02-14 272.1700
# 2023-02-15 269.3200
# 2023-02-16 262.1500
# 2023-02-17 258.0600
#
# [348 rows x 1 columns]

# %%
msft.rename(columns = {"MSFT":"Price"}, inplace = True)

# %%
msft
# Out:
#               Price
# Date
# 2021-10-01 289.1000
# 2021-10-04 283.1100
# 2021-10-05 288.7600
# 2021-10-06 293.1100
# 2021-10-07 294.8500
# ...             ...
# 2023-02-13 271.3200
# 2023-02-14 272.1700
# 2023-02-15 269.3200
# 2023-02-16 262.1500
# 2023-02-17 258.0600
#
# [348 rows x 1 columns]

# %%
msft.shift(periods = 1)
# Out:
#               Price
# Date
# 2021-10-01      NaN
# 2021-10-04 289.1000
# 2021-10-05 283.1100
# 2021-10-06 288.7600
# 2021-10-07 293.1100
# ...             ...
# 2023-02-13 263.1000
# 2023-02-14 271.3200
# 2023-02-15 272.1700
# 2023-02-16 269.3200
# 2023-02-17 262.1500
#
# [348 rows x 1 columns]

# %%
msft["P_lag1"] = msft.shift(periods = 1)
msft
# Out:
#               Price   P_lag1
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100 289.1000
# 2021-10-05 288.7600 283.1100
# 2021-10-06 293.1100 288.7600
# 2021-10-07 294.8500 293.1100
# ...             ...      ...
# 2023-02-13 271.3200 263.1000
# 2023-02-14 272.1700 271.3200
# 2023-02-15 269.3200 272.1700
# 2023-02-16 262.1500 269.3200
# 2023-02-17 258.0600 262.1500
#
# [348 rows x 2 columns]

# %%
# Absolute Price Changes (Difference)


msft["P_diff"] = msft.Price.sub(msft.P_lag1) # Alternative 1

# %%
msft
# Out:
#               Price   P_lag1  P_diff
# Date
# 2021-10-01 289.1000      NaN     NaN
# 2021-10-04 283.1100 289.1000 -5.9900
# 2021-10-05 288.7600 283.1100  5.6500
# 2021-10-06 293.1100 288.7600  4.3500
# 2021-10-07 294.8500 293.1100  1.7400
# ...             ...      ...     ...
# 2023-02-13 271.3200 263.1000  8.2200
# 2023-02-14 272.1700 271.3200  0.8500
# 2023-02-15 269.3200 272.1700 -2.8500
# 2023-02-16 262.1500 269.3200 -7.1700
# 2023-02-17 258.0600 262.1500 -4.0900
#
# [348 rows x 3 columns]

# %%
msft["P_diff2"] = msft.Price.diff(periods = 1)  # Alternative 2

# %%
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2
# Date
# 2021-10-01 289.1000      NaN     NaN      NaN
# 2021-10-04 283.1100 289.1000 -5.9900  -5.9900
# 2021-10-05 288.7600 283.1100  5.6500   5.6500
# 2021-10-06 293.1100 288.7600  4.3500   4.3500
# 2021-10-07 294.8500 293.1100  1.7400   1.7400
# ...             ...      ...     ...      ...
# 2023-02-13 271.3200 263.1000  8.2200   8.2200
# 2023-02-14 272.1700 271.3200  0.8500   0.8500
# 2023-02-15 269.3200 272.1700 -2.8500  -2.8500
# 2023-02-16 262.1500 269.3200 -7.1700  -7.1700
# 2023-02-17 258.0600 262.1500 -4.0900  -4.0900
#
# [348 rows x 4 columns]

# %%
msft.P_diff.equals(msft.P_diff2)
# Out:
# True

# %% [markdown]
# -> Absolute Price Changes are not meaningful
#
# Relative/Percentage Price Changes (Returns)

# %%
msft.Price.div(msft.P_lag1) - 1 # Alternative 1
# Out:
# Date
# 2021-10-01       NaN
# 2021-10-04   -0.0207
# 2021-10-05    0.0200
# 2021-10-06    0.0151
# 2021-10-07    0.0059
#                ...
# 2023-02-13    0.0312
# 2023-02-14    0.0031
# 2023-02-15   -0.0105
# 2023-02-16   -0.0266
# 2023-02-17   -0.0156
# Length: 348, dtype: float64

# %%
msft["Returns"] = msft.Price.pct_change(periods = 1) # Alternative 2
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2  Returns
# Date
# 2021-10-01 289.1000      NaN     NaN      NaN      NaN
# 2021-10-04 283.1100 289.1000 -5.9900  -5.9900  -0.0207
# 2021-10-05 288.7600 283.1100  5.6500   5.6500   0.0200
# 2021-10-06 293.1100 288.7600  4.3500   4.3500   0.0151
# 2021-10-07 294.8500 293.1100  1.7400   1.7400   0.0059
# ...             ...      ...     ...      ...      ...
# 2023-02-13 271.3200 263.1000  8.2200   8.2200   0.0312
# 2023-02-14 272.1700 271.3200  0.8500   0.8500   0.0031
# 2023-02-15 269.3200 272.1700 -2.8500  -2.8500  -0.0105
# 2023-02-16 262.1500 269.3200 -7.1700  -7.1700  -0.0266
# 2023-02-17 258.0600 262.1500 -4.0900  -4.0900  -0.0156
#
# [348 rows x 5 columns]

# %%
46.0900 / 45.7600 - 1
# Out:
# 0.007211538461538547

# %%
(46.0900 / 45.7600 - 1) * 100
# Out:
# 0.7211538461538547

# %%
# Take Home: Relative Price Changes (Returns) are meaningful and comparable across instruments

msft.drop(columns = ["P_lag1", "P_diff", "P_diff2"], inplace = True)

# %%
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %%
msft.to_csv("msft.csv")

# %% [markdown]
# # Measuring Reward and Risk of an Investment
# General Rule in Finance/Investing: Higher Risk must be rewarded with higher Returns.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %%
msft.Price.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# * Reward: Positive Returns
# * Risk: Volatility of Returns

# %%
msft.describe()
# Out:
#          Price  Returns
# count 348.0000 347.0000
# mean  277.0683  -0.0001
# std    33.0166   0.0210
# min   214.2500  -0.0772
# 25%   248.1200  -0.0128
# 50%   272.4600  -0.0010
# 75%   301.2800   0.0124
# max   343.1100   0.0823

# %%
mu = msft.Returns.mean() # arithmetic mean return -> Reward
mu
# Out:
# -0.00010794597435284932

# %%
sigma = msft.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# 0.020979269159438135

# %%
np.sqrt(msft.Returns.var())
# Out:
# 0.020979269159438135

# %% [markdown]
# # Coding Challenge #2

# %%
# Coding Challenge #2

# 1.Calculate daily returns for Bitcoin.
# 2.Calculate the arithmetic mean return and the standard deviation of returns for Bitcoin.
# 3.Compare Bitcoin with Microsoft (mu = 0.00116, sigma = 0.01726). Does the rule "Higher Risk -> Higher Reward" hold?

# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
btc = close["BTC-USD"].dropna().to_frame().copy()
btc
# Out:
#               BTC-USD
# Date
# 2021-10-01 48116.9414
# 2021-10-02 47711.4883
# 2021-10-03 48199.9531
# 2021-10-04 49112.9023
# 2021-10-05 51514.8125
# ...               ...
# 2023-02-11 21870.8750
# 2023-02-12 21788.2031
# 2023-02-13 21808.1016
# 2023-02-14 22220.8047
# 2023-02-15 24307.8418
#
# [503 rows x 1 columns]

# %%
btc["Returns"] = btc.pct_change(periods = 1)
btc
# Out:
#               BTC-USD  Returns
# Date
# 2021-10-01 48116.9414      NaN
# 2021-10-02 47711.4883  -0.0084
# 2021-10-03 48199.9531   0.0102
# 2021-10-04 49112.9023   0.0189
# 2021-10-05 51514.8125   0.0489
# ...               ...      ...
# 2023-02-11 21870.8750   0.0101
# 2023-02-12 21788.2031  -0.0038
# 2023-02-13 21808.1016   0.0009
# 2023-02-14 22220.8047   0.0189
# 2023-02-15 24307.8418   0.0939
#
# [503 rows x 2 columns]

# %%
btc
# Out:
#               BTC-USD  Returns
# Date
# 2021-10-01 48116.9414      NaN
# 2021-10-02 47711.4883  -0.0084
# 2021-10-03 48199.9531   0.0102
# 2021-10-04 49112.9023   0.0189
# 2021-10-05 51514.8125   0.0489
# ...               ...      ...
# 2023-02-11 21870.8750   0.0101
# 2023-02-12 21788.2031  -0.0038
# 2023-02-13 21808.1016   0.0009
# 2023-02-14 22220.8047   0.0189
# 2023-02-15 24307.8418   0.0939
#
# [503 rows x 2 columns]

# %%
mu = btc.Returns.mean() 
mu
# Out:
# -0.000826985191093398

# %%
sigma = btc.Returns.std()
sigma
# Out:
# 0.032513567202986246

# %%
mu > 0.00116
# Out:
# False

# %%
sigma > 0.01726
# Out:
# True

# %%
# Does the rule "Higher Risk -> Higher Reward" hold? -> Yes

# %% [markdown]
# # Investment Multiple and CAGR
# Two alternative reward metrics that are more intuitive and easier to interpret.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %% [markdown]
# Investment Multiple: Ending Value of 1 [Dollar] invested.
# Multiple = Ending Value / Initial Investment

# %%
multiple = (msft.Price[-1] / msft.Price[0])
multiple
# Out:
# 0.8926322798699364

# %%
# Price Increase (in %)

(multiple - 1) * 100
# Out:
# -10.736772013006357

# %%
msft.Price / msft.Price[0] # similar/identical concept: Normalized Price with Base Value 1
# Out:
# Date
# 2021-10-01   1.0000
# 2021-10-04   0.9793
# 2021-10-05   0.9988
# 2021-10-06   1.0139
# 2021-10-07   1.0199
#               ...
# 2023-02-13   0.9385
# 2023-02-14   0.9414
# 2023-02-15   0.9316
# 2023-02-16   0.9068
# 2023-02-17   0.8926
# Name: Price, Length: 348, dtype: float64

# %% [markdown]
# Drawback of Investment Multiple: Doesn´t take into account investment Period. Meaningful only in conjunction with Investment Period.
#
# Compound Annual Growth Rate (CAGR): The (constant annual) rate of return that would be required for an investment to grow from its beginning balance to its ending balance, assuming the profits were reinvested at the end of each year of the investment's lifespan. (Wikipedia)

# %%
start = msft.index[0]
start
# Out:
# Timestamp('2021-10-01 00:00:00')

# %%
end = msft.index[-1]
end
# Out:
# Timestamp('2023-02-17 00:00:00')

# %%
td = end - start
td
# Out:
# Timedelta('504 days 00:00:00')

# %%
td_years = td.days / 365.25
td_years
# Out:
# 1.379876796714579

# %%
cagr = multiple**(1 / td_years) - 1 # short version
cagr
# Out:
# -0.07901552988456484

# %%
cagr = (msft.Price[-1]/msft.Price[0])**(1/((msft.index[-1] - msft.index[0]).days / 365.25)) - 1 # long
cagr
# Out:
# -0.07901552988456484

# %%
(1 + cagr)**(td_years) # alternative #2 to calculate multiple (cagr)
# Out:
# 0.8926322798699363

# %%
# -> CAGR can be used to compare Investments with different investment horizons.

# %% [markdown]
# # Compound Returns & Geometric Mean Return

# %%
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %%
multiple = (1 + msft.Returns).prod() # alternative #3 to calculate multiple (compounding daily returns)
multiple
# Out:
# 0.8926322798699436

# %%
n = msft.Returns.count()
n
# Out:
# 347

# %%
geo_mean = multiple**(1/n) - 1 # Geometric mean return (daily)
geo_mean
# Out:
# -0.0003272679450103677

# %%
(1 + geo_mean)**n # alternative #4 to calculate multiple (geometric mean)
# Out:
# 0.8926322798699489

# %%
# -> Compound returns, CAGR & geometric mean return are closely related concepts.

mu = msft.Returns.mean() # arithmetic mean return
mu
# Out:
# -0.00010794597435284932

# %%
# The arithmetic mean return is always greater than the geometric mean return... and less useful.

(1 + mu)**n # calculate multiple? not possible with arithmetic mean!
# Out:
# 0.9632336446837371

# %% [markdown]
# # Coding Challenge #3

# %%
# Coding Challenge #3

#     1.Calculate Boeing´s Investment Multiple
#     2.Calculate Boeing´s CAGR
#     3.Calculate Boeing´s Geometric Mean Return
#     4.Calculate Boeing´s Investment Multiple with compound daily returns

# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
ba = close["BA"].dropna().to_frame().copy()
ba
# Out:
#                  BA
# Date
# 2021-10-01 226.0000
# 2021-10-04 223.7900
# 2021-10-05 224.4200
# 2021-10-06 224.9900
# 2021-10-07 226.4800
# ...             ...
# 2023-02-13 215.6500
# 2023-02-14 218.4500
# 2023-02-15 217.4400
# 2023-02-16 212.2100
# 2023-02-17 211.6600
#
# [348 rows x 1 columns]

# %%
ba["Returns"] = ba.pct_change(periods = 1)
ba
# Out:
#                  BA  Returns
# Date
# 2021-10-01 226.0000      NaN
# 2021-10-04 223.7900  -0.0098
# 2021-10-05 224.4200   0.0028
# 2021-10-06 224.9900   0.0025
# 2021-10-07 226.4800   0.0066
# ...             ...      ...
# 2023-02-13 215.6500   0.0130
# 2023-02-14 218.4500   0.0130
# 2023-02-15 217.4400  -0.0046
# 2023-02-16 212.2100  -0.0241
# 2023-02-17 211.6600  -0.0026
#
# [348 rows x 2 columns]

# %%
multiple = ba.BA[-1] / ba.BA[0]
multiple
# Out:
# 0.9365486887703952

# %%
cagr = (ba.BA[-1]/ba.BA[0])**(1/((ba.index[-1] - ba.index[0]).days / 365.25)) - 1 
cagr
# Out:
# -0.046396175388696004

# %%
n = ba.Returns.count()
n
# Out:
# 347

# %%
geo_mean = (1 + ba.Returns).prod()**(1/n) - 1 
geo_mean
# Out:
# -0.00018889791534526523

# %%
multiple = ba.Returns.add(1).prod()
multiple
# Out:
# 0.9365486887703954

# %% [markdown]
# # Preview: Simple Returns vs. Logarithmic Returns (log returns)
# Very often log returns are used instead of simple returns.
#
# favourable characteristics of log returns
# drawbacks of simple returns
# Problem: Many Students / Practitioners feel uncomfortable with log returns.
# -> more detailed background on log returns in the next two Lectures (Discrete vs. Continuous Compounding)

# %% [markdown]
# # Discrete Compounding
# Annual Compounding -> Interests accrue once a year at the end of the year
#
# Your Savings Bank offers an interest rate of 8% p.a. (stated rate) with annual compounding on your savings (USD 100).
# Calculate the value of your savings account after one year and the corresponding effective annual interest rate.
#
# -> Interests are calculated and added to your savings account once at the end of each year.

# %%
PV = 100
r = 0.08
n = 1

# %%
100 * 1.08
# Out:
# 108.0

# %%
FV = PV * (1 + r)**n
FV
# Out:
# 108.0

# %%
effective_annual_rate = (FV / PV)**(1/n) - 1 
effective_annual_rate
# Out:
# 0.08000000000000007

# %% [markdown]
# Quarterly Compounding -> Interests accrue once a quarter at the end of the quarter
#
# Your Savings Bank offers an interest rate of 8% p.a. (stated rate) with quarterly compounding on your savings (USD 100).
# Calculate the value of your savings account after one year and the corresponding effective annual interest rate.
#
# -> Interests are calculated and added to your savings account at the end of each quarter.

# %%
PV = 100
r = 0.08
n = 1
m = 4

# %%
100 * 1.02 * 1.02 * 1.02 * 1.02
# Out:
# 108.243216

# %%
FV = PV * (1 + r/m)**(n*m)
FV
# Out:
# 108.243216

# %%
effective_annual_rate = (FV / PV)**(1/n) - 1 
effective_annual_rate
# Out:
# 0.08243215999999998

# %% [markdown]
# -> Quarterly compounding is favourable (everything else equal) as we earn compound interest (interest on interest).
#
#
# Monthly Compounding -> Interests accrue once a month at the end of the month
#
# Your Savings Bank offers an interest rate of 8% p.a. (stated rate) with monthly compounding on your savings (USD 100).
# Calculate the value of your savings account after one year and the corresponding effective annual interest rate.
#
# -> Interests are calculated and added to your savings account at the end of each month.

# %%
PV = 100
r = 0.08
n = 1
m = 12

# %%
FV = PV * (1 + r/m)**(n*m)
FV
# Out:
# 108.29995068075098

# %%
effective_annual_rate = ((FV / PV)**(1/n) - 1) 
effective_annual_rate
# Out:
# 0.08299950680750978

# %% [markdown]
# # Continuous Compounding

# %%
import numpy as np

# %% [markdown]
# Your Savings Bank offers an interest rate of 8% p.a. (stated rate) with continuous compounding on your savings (USD 100).
# Calculate the value of your savings account after one year and the corresponding effective annual interest rate.
#
# -> Interests are calculated and added to your savings account continuously (infinitely large number of compounding events). -> continuous exponential growth that can be observed in nature

# %%
PV = 100
r = 0.08
n = 1
m = 100000 # approx.infinity

# %%
FV = PV * (1 + r/m)**(n*m) # approx. with large m
FV
# Out:
# 108.32870330122834

# %%
FV = PV * np.exp(n * r) # exact math with e (euler number)
FV
# Out:
# 108.32870676749586

# %%
euler = np.exp(1)
euler
# Out:
# 2.718281828459045

# %%
PV * euler**(n * r)
# Out:
# 108.32870676749586

# %%
effective_annual_rate = ((FV / PV)**(1/n) - 1) # Alt 1
effective_annual_rate
# Out:
# 0.08328706767495864

# %%
effective_annual_rate = np.exp(r) - 1 # Alt 2
effective_annual_rate
# Out:
# 0.08328706767495864

# %%
# Let´s assume we only observe PV and FV, how to calculate the stated rate/continuously compounded rate of 8%?

r = np.log(FV / PV) # inverse calculation -> use log (Alt 1)
r
# Out:
# 0.08000000000000007

# %%
r = np.log(effective_annual_rate + 1) # inverse calculation -> use log (Alt 2)
r
# Out:
# 0.08000000000000007

# %% [markdown]
# Take Home: Prices of traded Financial Instruments change (approx.) continuously.
# -> Intuitively, it makes a lot of sense to work with log returns.

# %% [markdown]
# # Log Returns

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#                 Price   Returns
# Date
# 2021-10-01 289.100006       NaN
# 2021-10-04 283.109985 -0.020720
# 2021-10-05 288.760010  0.019957
# 2021-10-06 293.109985  0.015064
# 2021-10-07 294.850006  0.005936
# ...               ...       ...
# 2023-02-13 271.320007  0.031243
# 2023-02-14 272.170013  0.003133
# 2023-02-15 269.320007 -0.010471
# 2023-02-16 262.149994 -0.026623
# 2023-02-17 258.059998 -0.015602
#
# [348 rows x 2 columns]

# %%
msft["log_ret"] = np.log(msft.Price / msft.Price.shift()) # daily log returns

# %%
msft
# Out:
#                 Price   Returns   log_ret
# Date
# 2021-10-01 289.100006       NaN       NaN
# 2021-10-04 283.109985 -0.020720 -0.020937
# 2021-10-05 288.760010  0.019957  0.019760
# 2021-10-06 293.109985  0.015064  0.014952
# 2021-10-07 294.850006  0.005936  0.005919
# ...               ...       ...       ...
# 2023-02-13 271.320007  0.031243  0.030765
# 2023-02-14 272.170013  0.003133  0.003128
# 2023-02-15 269.320007 -0.010471 -0.010527
# 2023-02-16 262.149994 -0.026623 -0.026983
# 2023-02-17 258.059998 -0.015602 -0.015725
#
# [348 rows x 3 columns]

# %%
msft.describe()
# Out:
#            Price    Returns    log_ret
# count 348.000000 347.000000 347.000000
# mean  277.068276  -0.000108  -0.000327
# std    33.016625   0.020979   0.020976
# min   214.250000  -0.077156  -0.080295
# 25%   248.120003  -0.012775  -0.012857
# 50%   272.460007  -0.001001  -0.001001
# 75%   301.279999   0.012355   0.012280
# max   343.109985   0.082268   0.079059

# %%
mu = msft.log_ret.mean() # mean log return -> Reward
mu
# Out:
# -0.00032732150885112746

# %%
sigma = msft.log_ret.std() # standard deviation of log returns -> Risk/Volatility
sigma
# Out:
# 0.020975603058517915

# %% [markdown]
# # Simple Returns vs Log Returns ( Part 1)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
df = pd.DataFrame(data = [100, 50, 90], columns = ["Price"])
df
# Out:
#    Price
# 0    100
# 1     50
# 2     90

# %%
df["SR"] = df.Price.pct_change() # simple returns

# %%
df["LR"] = np.log(df.Price / df.Price.shift()) # log returns

# %%
df
# Out:
#    Price        SR        LR
# 0    100       NaN       NaN
# 1     50 -0.500000 -0.693147
# 2     90  0.800000  0.587787

# %%
periods = df.SR.count()
periods
# Out:
# 2

# %%
# The arithmetic mean of simple returns can be misleading!

mean_sr = df.SR.mean()
mean_sr
# Out:
# 0.15000000000000002

# %%
100 * (1 + mean_sr)**periods # wrong!!!
# Out:
# 132.24999999999997

# %%
# We should use Compound Simple Returns / Geometric Mean, or even better...

geo_mean = (1 + df.SR).prod()**(1 / periods) - 1
geo_mean
# Out:
# -0.05131670194948623

# %%
100 * (1 + geo_mean)**periods # correct!!!
# Out:
# 89.99999999999999

# %%
# ...Log Returns which are additive over time!

sum_lr = df.LR.sum()
sum_lr
# Out:
# -0.10536051565782623

# %%
100 * np.exp(sum_lr) # correct!!!
# Out:
# 90.0

# %%
mean_lr = df.LR.mean()
mean_lr
# Out:
# -0.05268025782891311

# %%
100 * np.exp(mean_lr * periods) # correct!!!
# Out:
# 90.0

# %% [markdown]
# Take Home: Log Returns are additive over time. Simple Returns are not additive over time (but they can be multiplied/compounded)

# %% [markdown]
# # Simple Returns vs. Log Returns (Part 2)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])

# %%
msft["log_ret"] = np.log(msft.Price / msft.Price.shift())

# %%
msft
# Out:
#                 Price   Returns   log_ret
# Date
# 2021-10-01 289.100006       NaN       NaN
# 2021-10-04 283.109985 -0.020720 -0.020937
# 2021-10-05 288.760010  0.019957  0.019760
# 2021-10-06 293.109985  0.015064  0.014952
# 2021-10-07 294.850006  0.005936  0.005919
# ...               ...       ...       ...
# 2023-02-13 271.320007  0.031243  0.030765
# 2023-02-14 272.170013  0.003133  0.003128
# 2023-02-15 269.320007 -0.010471 -0.010527
# 2023-02-16 262.149994 -0.026623 -0.026983
# 2023-02-17 258.059998 -0.015602 -0.015725
#
# [348 rows x 3 columns]

# %%
# Investment Multiple

msft.Returns.add(1).prod() # compounding simple returns ("compound returns")
# Out:
# 0.8926322798699436

# %%
np.exp(msft.log_ret.sum())  # adding log returns ("cumulative returns")
# Out:
# 0.8926322798699364

# %%
# Normalized Prices with Base 1

msft.Returns.add(1).cumprod() # compounding simple returns ("compound returns")
# Out:
# Date
# 2021-10-01        NaN
# 2021-10-04   0.979280
# 2021-10-05   0.998824
# 2021-10-06   1.013871
# 2021-10-07   1.019889
#                ...
# 2023-02-13   0.938499
# 2023-02-14   0.941439
# 2023-02-15   0.931581
# 2023-02-16   0.906780
# 2023-02-17   0.892632
# Name: Returns, Length: 348, dtype: float64

# %%
np.exp(msft.log_ret.cumsum()) # adding log returns ("cumulative returns")
# Out:
# Date
# 2021-10-01        NaN
# 2021-10-04   0.979280
# 2021-10-05   0.998824
# 2021-10-06   1.013871
# 2021-10-07   1.019889
#                ...
# 2023-02-13   0.938499
# 2023-02-14   0.941439
# 2023-02-15   0.931581
# 2023-02-16   0.906780
# 2023-02-17   0.892632
# Name: log_ret, Length: 348, dtype: float64

# %%
msft.log_ret.cumsum().apply(np.exp) # adding log returns ("cumulative returns")
# Out:
# Date
# 2021-10-01        NaN
# 2021-10-04   0.979280
# 2021-10-05   0.998824
# 2021-10-06   1.013871
# 2021-10-07   1.019889
#                ...
# 2023-02-13   0.938499
# 2023-02-14   0.941439
# 2023-02-15   0.931581
# 2023-02-16   0.906780
# 2023-02-17   0.892632
# Name: log_ret, Length: 348, dtype: float64

# %% [markdown]
# CAGR

# %%
(msft.Price[-1]/msft.Price[0])**(1/((msft.index[-1] - msft.index[0]).days / 365.25)) - 1
# Out:
# -0.07901552988456484

# %%
trading_days_year = msft.Returns.count() / ((msft.index[-1] - msft.index[0]).days / 365.25)
trading_days_year
# Out:
# 251.47172619047618

# %%
np.exp(msft.log_ret.mean() * trading_days_year) - 1 # correct with mean of daily log returns!
# Out:
# -0.07901552988456473

# %%
msft.Returns.mean() * trading_days_year # incorrect with mean of daily simple returns!
# Out:
# -0.02714536050582389

# %%
np.exp(msft.log_ret.mean() * 252) - 1 # good approximation (for us stocks)
# Out:
# -0.07917476849677618

# %% [markdown]
# # Coding Challenge #4

# %%
# Coding Challenge #4

#     1.Calculate daily log returns for Boeing.
#     2.Use Boeing´s log returns to calculate
#     * Investment Multiple
#     * CAGR (assuming 252 trading days)
#     * Normalized Prices (Base = 1)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
ba = close["BA"].dropna().to_frame().copy()
ba
# Out:
#                  BA
# Date
# 2021-10-01 226.0000
# 2021-10-04 223.7900
# 2021-10-05 224.4200
# 2021-10-06 224.9900
# 2021-10-07 226.4800
# ...             ...
# 2023-02-13 215.6500
# 2023-02-14 218.4500
# 2023-02-15 217.4400
# 2023-02-16 212.2100
# 2023-02-17 211.6600
#
# [348 rows x 1 columns]

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba
# Out:
#                  BA  log_ret
# Date
# 2021-10-01 226.0000      NaN
# 2021-10-04 223.7900  -0.0098
# 2021-10-05 224.4200   0.0028
# 2021-10-06 224.9900   0.0025
# 2021-10-07 226.4800   0.0066
# ...             ...      ...
# 2023-02-13 215.6500   0.0129
# 2023-02-14 218.4500   0.0129
# 2023-02-15 217.4400  -0.0046
# 2023-02-16 212.2100  -0.0243
# 2023-02-17 211.6600  -0.0026
#
# [348 rows x 2 columns]

# %%
multiple = np.exp(ba.log_ret.sum())
multiple
# Out:
# 0.9365486887703952

# %%
cagr = np.exp(ba.log_ret.mean() * 252) - 1
cagr
# Out:
# -0.046491339584147306

# %%
norm = ba.log_ret.cumsum().apply(np.exp)
norm
# Out:
# Date
# 2021-10-01      NaN
# 2021-10-04   0.9902
# 2021-10-05   0.9930
# 2021-10-06   0.9955
# 2021-10-07   1.0021
#               ...
# 2023-02-13   0.9542
# 2023-02-14   0.9666
# 2023-02-15   0.9621
# 2023-02-16   0.9390
# 2023-02-17   0.9365
# Name: log_ret, Length: 348, dtype: float64

# %% [markdown]
# # Performance Comparison
# General Rule in Finance/Investing: Higher Risk must be rewarded with higher Returns.
#
# Which instrument(s) performed best/worst in the past in terms of risk & return?

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        348 non-null    float64
#  1   BTC-USD   503 non-null    float64
#  2   EURUSD=X  361 non-null    float64
#  3   GC=F      350 non-null    float64
#  4   MSFT      348 non-null    float64
#  5   ^DJI      348 non-null    float64
# dtypes: float64(6)
# memory usage: 27.6 KB

# %%
close.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
np.log(close / close.shift()).info() # keep NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        273 non-null    float64
#  1   BTC-USD   502 non-null    float64
#  2   EURUSD=X  288 non-null    float64
#  3   GC=F      276 non-null    float64
#  4   MSFT      273 non-null    float64
#  5   ^DJI      273 non-null    float64
# dtypes: float64(6)
# memory usage: 27.6 KB

# %%
close.apply(lambda x: np.log(x.dropna() / x.dropna().shift())).info() # remove NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Freq: D
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        347 non-null    float64
#  1   BTC-USD   502 non-null    float64
#  2   EURUSD=X  360 non-null    float64
#  3   GC=F      349 non-null    float64
#  4   MSFT      347 non-null    float64
#  5   ^DJI      347 non-null    float64
# dtypes: float64(6)
# memory usage: 27.6 KB

# %%
returns = close.apply(lambda x: np.log(x.dropna() / x.dropna().shift()))
returns
# Out:
#                 BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI
# Date
# 2021-10-01     NaN      NaN       NaN     NaN     NaN     NaN
# 2021-10-02     NaN  -0.0085       NaN     NaN     NaN     NaN
# 2021-10-03     NaN   0.0102       NaN     NaN     NaN     NaN
# 2021-10-04 -0.0098   0.0188    0.0028  0.0052 -0.0209 -0.0095
# 2021-10-05  0.0028   0.0477    0.0010 -0.0037  0.0198  0.0091
# ...            ...      ...       ...     ...     ...     ...
# 2023-02-13  0.0129   0.0009   -0.0060 -0.0059  0.0308  0.0111
# 2023-02-14  0.0129   0.0187    0.0049  0.0011  0.0031 -0.0046
# 2023-02-15 -0.0046   0.0898    0.0005 -0.0107 -0.0105  0.0011
# 2023-02-16 -0.0243      NaN   -0.0041  0.0042 -0.0270 -0.0127
# 2023-02-17 -0.0026      NaN   -0.0024  0.0050 -0.0157  0.0038
#
# [505 rows x 6 columns]

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 505 entries, 2021-10-01 to 2023-02-17
# Freq: D
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        347 non-null    float64
#  1   BTC-USD   502 non-null    float64
#  2   EURUSD=X  360 non-null    float64
#  3   GC=F      349 non-null    float64
#  4   MSFT      347 non-null    float64
#  5   ^DJI      347 non-null    float64
# dtypes: float64(6)
# memory usage: 27.6 KB

# %%
returns.describe()
# Out:
#             BA  BTC-USD  EURUSD=X     GC=F     MSFT     ^DJI
# count 347.0000 502.0000  360.0000 349.0000 347.0000 347.0000
# mean   -0.0002  -0.0014   -0.0002   0.0001  -0.0003  -0.0000
# std     0.0275   0.0328    0.0057   0.0093   0.0210   0.0115
# min    -0.1106  -0.1741   -0.0175  -0.0283  -0.0803  -0.0402
# 25%    -0.0124  -0.0142   -0.0034  -0.0049  -0.0129  -0.0061
# 50%    -0.0004  -0.0010   -0.0001   0.0004  -0.0010   0.0000
# 75%     0.0139   0.0148    0.0030   0.0052   0.0123   0.0066
# max     0.0904   0.1358    0.0182   0.0311   0.0791   0.0363

# %%
summary = returns.agg(["mean", "std"]).T
summary
# Out:
#             mean    std
# BA       -0.0002 0.0275
# BTC-USD  -0.0014 0.0328
# EURUSD=X -0.0002 0.0057
# GC=F      0.0001 0.0093
# MSFT     -0.0003 0.0210
# ^DJI     -0.0000 0.0115

# %%
summary.columns = ["Mean", "Std"]
summary
# Out:
#             Mean    Std
# BA       -0.0002 0.0275
# BTC-USD  -0.0014 0.0328
# EURUSD=X -0.0002 0.0057
# GC=F      0.0001 0.0093
# MSFT     -0.0003 0.0210
# ^DJI     -0.0000 0.0115

# %%
summary.plot(kind = "scatter", x = "Std", y = "Mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "Std"]+0.00005, summary.loc[i, "Mean"]+0.00005), size = 15)
plt.xlabel("Risk (std)", fontsize = 15)
plt.ylabel("Mean Return", fontsize = 15)
plt.title("Mean-Variance Analysis", fontsize = 20)
plt.show()

# %%
# -> There is no clear "best-performer" among ["EURUSD=X", "GC=F", "^DJI", "MSFT", "BTC-USD"]
#  (without further analysis). Higher risk is getting rewarded with higher returns. BA underperformed.

# %%
# Take Home: Mean-Variance Analysis has one major shortcoming: It assumes that financial returns follow a Normal Distribution. That´s (typically) not True.
# -> Standard Deviation of Returns underestimates the true/full risk of an Investment as it fails to measure "Tail Risks".

# %% [markdown]
# # Normality of Financial Returns

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %%
msft["log_ret"] = np.log(msft.Price / msft.Price.shift()) 
msft
# Out:
#               Price  Returns  log_ret
# Date
# 2021-10-01 289.1000      NaN      NaN
# 2021-10-04 283.1100  -0.0207  -0.0209
# 2021-10-05 288.7600   0.0200   0.0198
# 2021-10-06 293.1100   0.0151   0.0150
# 2021-10-07 294.8500   0.0059   0.0059
# ...             ...      ...      ...
# 2023-02-13 271.3200   0.0312   0.0308
# 2023-02-14 272.1700   0.0031   0.0031
# 2023-02-15 269.3200  -0.0105  -0.0105
# 2023-02-16 262.1500  -0.0266  -0.0270
# 2023-02-17 258.0600  -0.0156  -0.0157
#
# [348 rows x 3 columns]

# %%
msft.describe()
# Out:
#          Price  Returns  log_ret
# count 348.0000 347.0000 347.0000
# mean  277.0683  -0.0001  -0.0003
# std    33.0166   0.0210   0.0210
# min   214.2500  -0.0772  -0.0803
# 25%   248.1200  -0.0128  -0.0129
# 50%   272.4600  -0.0010  -0.0010
# 75%   301.2800   0.0124   0.0123
# max   343.1100   0.0823   0.0791

# %%
msft.log_ret.plot(kind = "hist", figsize = (15 ,8), bins = 100, fontsize = 15, density = False) # Frequency Distribution of log returns
plt.xlabel("Daily Returns", fontsize = 15)
plt.ylabel("Frequency", fontsize = 15)
plt.title("Frequency Distribution of Returns", fontsize = 20)
plt.show()

# %%
# Do MSFT Returns follow a Normal Distribution? 

# A normally distributed random variable can be fully described by its

#   * mean
#   * standard deviation
# Higher Central Moments are zero:

#   * Skew = 0 (measures symmetrie around the mean)
#   * (Excess) Kurtosis = 0 (positve excess Kurtosis -> more observations in the "tails")

# %%
mu = msft.log_ret.mean()
mu
# Out:
# -0.00032732150885112746

# %%
sigma = msft.log_ret.std()
sigma
# Out:
# 0.020975603058517915

# %%
import scipy.stats as stats

# %%
stats.skew(msft.log_ret.dropna()) # in a Normal Distribution: skew == 0
# Out:
# 0.0055850429551665606

# %%
stats.kurtosis(msft.log_ret.dropna(), fisher = True) # in a Normal Distribution: (fisher) kurtosis == 0
# Out:
# 0.8917672315479033

# %%
# > MSFT Returns exhibit "Fat Tails" (extreme positive/negative outcomes).

x = np.linspace(msft.log_ret.min(), msft.log_ret.max(), 10000)
x
# Out:
# array([-0.08029539, -0.08027945, -0.08026351, ...,  0.07902702,
#         0.07904296,  0.07905889])

# %%
y = stats.norm.pdf(x, loc = mu, scale = sigma) # creating y values a for normal distribution with mu, sigma
y
# Out:
# array([0.01327512, 0.01331363, 0.01335224, ..., 0.01483534, 0.01479275,
#        0.01475028])

# %%
plt.figure(figsize = (20, 8))
plt.hist(msft.log_ret, bins = 500, density = True, label = "Frequency Distribution of daily Returns (MSFT)")
plt.plot(x, y, linewidth = 3, color = "red", label = "Normal Distribution")
plt.title("Normal Distribution", fontsize = 20)
plt.xlabel("Daily Returns", fontsize = 15)
plt.ylabel("pdf", fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# -> MSFT Returns exhibit "Fat Tails" (extreme positive/negative outcomes).

# Testing the normality of MSFT Returns based on the sample (Oct 2014 to May 2021): 
# -> Hypothesis Test with H0 Hypothesis: MSFT Returns (full population) follow a normal Distribution.

# %%
z_stat, p_value = stats.normaltest(msft.log_ret.dropna())

# %%
z_stat # high values -> reject H0
# Out:
# 7.213447135748968

# %%
p_value # low values (close to zero) -> reject H0
# Out:
# 0.02714062576607727

# %%
round(p_value, 10)
# Out:
# 0.0271406258

# %%
# -> Assuming that MSFT Returns (generally) follow a Normal Distribution,
#  there is 0% probability that we get that extreme outcomes in a sample.

# Take Home: MSFT Returns don´t follow a Normal Distribution as they 
# exhibit "Fat Tails". Extreme Events/Outcomes are not reflected in the Mean-Variance Analysis. 
# The Standard Deviation of Returns underestimates true Risk.

# %% [markdown]
# # Annualizing Mean Return and Std of Returns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.6f}'.format
plt.style.use("seaborn")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"], usecols = ["Date", "Price"])

# %%
msft
# Out:
#                 Price
# Date
# 2021-10-01 289.100006
# 2021-10-04 283.109985
# 2021-10-05 288.760010
# 2021-10-06 293.109985
# 2021-10-07 294.850006
# ...               ...
# 2023-02-13 271.320007
# 2023-02-14 272.170013
# 2023-02-15 269.320007
# 2023-02-16 262.149994
# 2023-02-17 258.059998
#
# [348 rows x 1 columns]

# %%
msft["log_ret"] = np.log(msft.Price / msft.Price.shift())

# %%
msft.log_ret.agg(["mean", "std"]) # mean and std based on daily returns
# Out:
# mean   -0.000327
# std     0.020976
# Name: log_ret, dtype: float64

# %%
ann_mu = msft.log_ret.mean() * 252 
ann_mu
# Out:
# -0.08248502023048412

# %%
cagr = np.exp(ann_mu) - 1 # don´t mix up with cagr
cagr
# Out:
# -0.07917476849677618

# %%
ann_std = msft.log_ret.std() * np.sqrt(252) 
ann_std
# Out:
# 0.3329773757546653

# %%
ann_std = np.sqrt(msft.log_ret.var() * 252) # annualized std of returns (Alt 2)
ann_std
# Out:
# 0.33297737575466524

# %% [markdown]
# # Resampling / Smoothing

# %%
msft.Price.plot(figsize = (12, 8))
plt.legend()
plt.show()

# %%
monthly = msft.Price.resample("M").last() ## resample to monthly (month end)
monthly
# Out:
# Date
# 2021-10-31   331.619995
# 2021-11-30   330.589996
# 2021-12-31   336.320007
# 2022-01-31   310.980011
# 2022-02-28   298.790009
# 2022-03-31   308.309998
# 2022-04-30   277.519989
# 2022-05-31   271.869995
# 2022-06-30   256.829987
# 2022-07-31   280.739990
# 2022-08-31   261.470001
# 2022-09-30   232.899994
# 2022-10-31   232.130005
# 2022-11-30   255.139999
# 2022-12-31   239.820007
# 2023-01-31   247.809998
# 2023-02-28   258.059998
# Freq: M, Name: Price, dtype: float64

# %%
monthly.plot(figsize = (12, 8))
plt.legend()
plt.show()

# %%
# How will the Mean-Variance Analysis change with smoothed data?

freqs = ["A", "Q", "M", "W-Fri", "D"]
periods = [1, 4, 12, 52, 252]
ann_mean = []
ann_std = []

# %%
for i in range(5):
    resamp = msft.Price.resample(freqs[i]).last() # resample
    ann_mean.append(np.log(resamp / resamp.shift()).mean() * periods[i]) # calc. annualized mean
    ann_std.append(np.log(resamp / resamp.shift()).std() * np.sqrt(periods[i])) # calc. annualized std

# %%
ann_mean
# Out:
# [-0.13243550145151534,
#  -0.21189680232242444,
#  -0.1880982103395167,
#  -0.0820304070237466,
#  0.012578758207747634]

# %%
ann_std

# %%
summary = pd.DataFrame(data = {"ann_std":ann_std, "ann_mean":ann_mean}, index = freqs)
summary
# Out:
#        ann_std  ann_mean
# A     0.290959 -0.132436
# Q     0.206647 -0.211897
# M     0.222151 -0.188098
# W-Fri 0.301515 -0.082030
# D     0.343816  0.012579

# %%
summary.plot(kind = "scatter", x = "ann_std", y = "ann_mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "ann_std"]+0.001, summary.loc[i, "ann_mean"]+0.001), size = 15)
plt.ylim(0, 0.3)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# -> Smoothing reduces (observed) Risk.
#
# Dubious practices:
#
# Managing (Manipulating) Performance in Performance Reportings.
# Comparing assets with different granularity and pricing mechanisms -> e.g. non-listed (alternative assets) vs. listed assets
# Adjusting granularity to investor´s (average) holding period -> Volatility is still there.

# %% [markdown]
# # Rolling Statistics
# (Another) general Rule in Finance/Investing: Past performance is not an indicator of future performance.

# %%
msft
# Out:
#                 Price   log_ret
# Date
# 2021-10-01 289.100006       NaN
# 2021-10-04 283.109985 -0.020937
# 2021-10-05 288.760010  0.019760
# 2021-10-06 293.109985  0.014952
# 2021-10-07 294.850006  0.005919
# ...               ...       ...
# 2023-02-13 271.320007  0.030765
# 2023-02-14 272.170013  0.003128
# 2023-02-15 269.320007 -0.010527
# 2023-02-16 262.149994 -0.026983
# 2023-02-17 258.059998 -0.015725
#
# [348 rows x 2 columns]

# %%
ann_mu = msft.log_ret.mean() * 252 # annualized mean return
ann_mu
# Out:
# -0.08248502023048412

# %%
ann_std = msft.log_ret.std() * np.sqrt(252) # annualized std of returns (Alt 1)
ann_std
# Out:
# 0.3329773757546653

# %% [markdown]
# Are Return and Risk constant over time? No, of course not! They change over time.
#
# Let´s measure/quantify this with rolling statistics!

# %%
window = 252 # rolling window 252 trading days (~ 1 Year)

# %%
msft.log_ret.rolling(window = 252)
# Out:
# Rolling [window=252,center=False,axis=0,method=single]

# %%
msft.log_ret.rolling(window = 252).sum() # Alt 1
# Out:
# Date
# 2021-10-01         NaN
# 2021-10-04         NaN
# 2021-10-05         NaN
# 2021-10-06         NaN
# 2021-10-07         NaN
#                 ...
# 2023-02-13   -0.108386
# 2023-02-14   -0.080684
# 2023-02-15   -0.091075
# 2023-02-16   -0.136431
# 2023-02-17   -0.148922
# Name: log_ret, Length: 348, dtype: float64

# %%
roll_mean = msft.log_ret.rolling(window = 252).mean() * 252 # Alt 2
roll_mean
# Out:
# Date
# 2021-10-01         NaN
# 2021-10-04         NaN
# 2021-10-05         NaN
# 2021-10-06         NaN
# 2021-10-07         NaN
#                 ...
# 2023-02-13   -0.108386
# 2023-02-14   -0.080684
# 2023-02-15   -0.091075
# 2023-02-16   -0.136431
# 2023-02-17   -0.148922
# Name: log_ret, Length: 348, dtype: float64

# %%
roll_mean.iloc[250:]
# Out:
# Date
# 2022-09-29         NaN
# 2022-09-30         NaN
# 2022-10-03   -0.183055
# 2022-10-04   -0.128865
# 2022-10-05   -0.147340
#                 ...
# 2023-02-13   -0.108386
# 2023-02-14   -0.080684
# 2023-02-15   -0.091075
# 2023-02-16   -0.136431
# 2023-02-17   -0.148922
# Name: log_ret, Length: 98, dtype: float64

# %%
roll_mean.plot(figsize = (12, 8))
plt.show()

# %%
roll_std = msft.log_ret.rolling(window = 252).std() * np.sqrt(252)
roll_std
# Out:
# Date
# 2021-10-01        NaN
# 2021-10-04        NaN
# 2021-10-05        NaN
# 2021-10-06        NaN
# 2021-10-07        NaN
#                ...
# 2023-02-13   0.356953
# 2023-02-14   0.356146
# 2023-02-15   0.356292
# 2023-02-16   0.356784
# 2023-02-17   0.357097
# Name: log_ret, Length: 348, dtype: float64

# %%
roll_std.plot(figsize = (12, 8))
plt.show()

# %%
roll_mean.plot(figsize = (12, 8))
roll_std.plot()
plt.show()

# %%
# Take Home: Be careful, you´ll always find (sub-)periods with low returns & high risk and high returns & low risk.

#    * Analysis Period must be sufficiently long to reduce impact of random noise. 
#    * Analysis Period should be as short as possible and should only include the latest trends / regimes.
#    * Commonly used reporting period: 3 Years / 36 Months
# Another Example: Simple Moving Average (Prices) - SMA

# %%
sma_window = 50

# %%
msft.Price.plot(figsize = (12, 8))
msft.Price.rolling(sma_window).mean().plot()
plt.show()

# %% [markdown]
# # Coding Challenge #5

# %%
# Coding Challenge #5

#   1.Calculate daily log returns for Boeing.

#   2.Use Boeing´s daily log returns to calculate the annualized mean and annualized std (assume 252 trading days per year).

#   3.Resample to monthly prices and compare the annualized std (monthly) with the annualized std (daily). Any differences?

#   4.Keep working with monthly data and calculate/visualize the rolling 36 months mean return (annualized).

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
ba = close["BA"].dropna().to_frame().copy()
ba
# Out:
#                  BA
# Date
# 2021-10-01 226.0000
# 2021-10-04 223.7900
# 2021-10-05 224.4200
# 2021-10-06 224.9900
# 2021-10-07 226.4800
# ...             ...
# 2023-02-13 215.6500
# 2023-02-14 218.4500
# 2023-02-15 217.4400
# 2023-02-16 212.2100
# 2023-02-17 211.6600
#
# [348 rows x 1 columns]

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba
# Out:
#                  BA  log_ret
# Date
# 2021-10-01 226.0000      NaN
# 2021-10-04 223.7900  -0.0098
# 2021-10-05 224.4200   0.0028
# 2021-10-06 224.9900   0.0025
# 2021-10-07 226.4800   0.0066
# ...             ...      ...
# 2023-02-13 215.6500   0.0129
# 2023-02-14 218.4500   0.0129
# 2023-02-15 217.4400  -0.0046
# 2023-02-16 212.2100  -0.0243
# 2023-02-17 211.6600  -0.0026
#
# [348 rows x 2 columns]

# %%
ann_mu = ba.log_ret.mean() * 252 
ann_mu
# Out:
# -0.04760677121851414

# %%
ann_std = ba.log_ret.std() * np.sqrt(252) 
ann_std
# Out:
# 0.43733110232506683

# %%
monthly = ba.BA.resample("M").last().to_frame()
monthly
# Out:
#                  BA
# Date
# 2021-10-31 207.0300
# 2021-11-30 197.8500
# 2021-12-31 201.3200
# 2022-01-31 200.2400
# 2022-02-28 205.3400
# 2022-03-31 191.5000
# 2022-04-30 148.8400
# 2022-05-31 131.4000
# 2022-06-30 136.7200
# 2022-07-31 159.3100
# 2022-08-31 160.2500
# 2022-09-30 121.0800
# 2022-10-31 142.5100
# 2022-11-30 178.8800
# 2022-12-31 190.4900
# 2023-01-31 213.0000
# 2023-02-28 211.6600

# %%
monthly["Returns"] = np.log(monthly / monthly.shift())
monthly
# Out:
#                  BA  Returns
# Date
# 2021-10-31 207.0300      NaN
# 2021-11-30 197.8500  -0.0454
# 2021-12-31 201.3200   0.0174
# 2022-01-31 200.2400  -0.0054
# 2022-02-28 205.3400   0.0252
# 2022-03-31 191.5000  -0.0698
# 2022-04-30 148.8400  -0.2520
# 2022-05-31 131.4000  -0.1246
# 2022-06-30 136.7200   0.0397
# 2022-07-31 159.3100   0.1529
# 2022-08-31 160.2500   0.0059
# 2022-09-30 121.0800  -0.2803
# 2022-10-31 142.5100   0.1630
# 2022-11-30 178.8800   0.2273
# 2022-12-31 190.4900   0.0629
# 2023-01-31 213.0000   0.1117
# 2023-02-28 211.6600  -0.0063

# %%
ann_std = monthly.Returns.std() * np.sqrt(12) 
ann_std
# Out:
# 0.4776171370707202

# %%
# -> Risk (monthly) slighly lower than Risk (daily)

window = 36

# %%
roll_mean = monthly.Returns.rolling(window = window).mean() * 12
roll_mean
# Out:
# Date
# 2021-10-31   NaN
# 2021-11-30   NaN
# 2021-12-31   NaN
# 2022-01-31   NaN
# 2022-02-28   NaN
# 2022-03-31   NaN
# 2022-04-30   NaN
# 2022-05-31   NaN
# 2022-06-30   NaN
# 2022-07-31   NaN
# 2022-08-31   NaN
# 2022-09-30   NaN
# 2022-10-31   NaN
# 2022-11-30   NaN
# 2022-12-31   NaN
# 2023-01-31   NaN
# 2023-02-28   NaN
# Freq: M, Name: Returns, dtype: float64

# %%
roll_mean.plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# # Short Selling / Short Positions (Part 1)
# What´s the rational behind short selling an instrument?
# -> making profits/positive returns when prices fall.
#
# Stocks Example:
#
# Today an Investor buys the ABC Stock for USD 100. One day later he sells the stock for USD 110.
# -> Profit: USD 10
# ->Long Position (benefit from rising prices):
#
# Today an Investor borrows the ABC Stock from another Investor and sells it for USD 100. One day later he buys the stock for USD 90 and returns it to the lender.
# -> Profit: USD 10
# ->Short Position (benefit from falling prices):
#
# In some countries (and for some instruments like stocks) short selling is prohibited.
# Most intuitive/popular use case for short selling: Currencies (Forex)

# %% [markdown]
# # Short Selling / Short Positions (Part 2)
# EUR/USD ("Long Euro" == "Short USD")

# %%
t0 = 1.10
t1 = 1.25

# %% [markdown]
# Today an Investor buys EUR 1 and pays USD 1.10. One day later he sells EUR 1 for USD 1.25
# -> Profit: USD 0.15
# ->Long Position Euro (benefit from rising EUR prices):

# %%
t1 / t0 - 1 # The EUR appreciates by 13.64% relative to USD (simple return)
# Out:
# 0.13636363636363624

# %% [markdown]
# -> EUR Long Position returns +13.64% (simple return)
#
# What return would you expect for the corresponding EUR Short position? That´s a "no brainer": -13.64%, right?
#
# Surprisingly, that´s incorrect!!!

# %%
# Inverse Rate: USD/EUR ("Short Euro" == "Long USD")

# %%
t0 = 1 / 1.10
t1 = 1 / 1.25

# %%
print(t0, t1)
# Out:
# 0.9090909090909091 0.8

# %% [markdown]
# Today an Investor buys USD 1 and pays 0.9091 Euro. One day later he sells USD 1 for EUR 0.8
# -> Loss: EUR 0.1091

# %%
t1 / t0 - 1 # The USD depreciates by 12.0% relative to EUR
# Out:
# -0.11999999999999988

# %% [markdown]
# -> EUR Short Position returns -12.0% (simple return)
#
# Take Home: When using simple returns, long position return != short position return * (-1)
# -> Use log returns!

# %% [markdown]
# # Short Selling / Short Positions (Part 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.6f}'.format
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                    BA      BTC-USD  EURUSD=X        GC=F       MSFT  \
# Date
# 2021-10-01 226.000000 48116.941406  1.157448 1757.000000 289.100006
# 2021-10-02        NaN 47711.488281       NaN         NaN        NaN
# 2021-10-03        NaN 48199.953125       NaN         NaN        NaN
# 2021-10-04 223.789993 49112.902344  1.160726 1766.199951 283.109985
# 2021-10-05 224.419998 51514.812500  1.161845 1759.599976 288.760010
# ...               ...          ...       ...         ...        ...
# 2023-02-13 215.649994 21808.101562  1.067771 1851.900024 271.320007
# 2023-02-14 218.449997 22220.804688  1.073042 1854.000000 272.170013
# 2023-02-15 217.440002 24307.841797  1.073572 1834.199951 269.320007
# 2023-02-16 212.210007          NaN  1.069176 1842.000000 262.149994
# 2023-02-17 211.660004          NaN  1.066576 1851.300049 258.059998
#
#                    ^DJI
# Date
# 2021-10-01 34326.460938
# 2021-10-02          NaN
# 2021-10-03          NaN
# 2021-10-04 34002.921875
# 2021-10-05 34314.671875
# ...                 ...
# 2023-02-13 34245.929688
# 2023-02-14 34089.269531
# 2023-02-15 34128.050781
# 2023-02-16 33696.851562
# 2023-02-17 33826.691406
#
# [505 rows x 6 columns]

# %%
close["USDEUR=X"] = 1/close["EURUSD=X"]

# %%
close
# Out:
#                    BA      BTC-USD  EURUSD=X        GC=F       MSFT  \
# Date
# 2021-10-01 226.000000 48116.941406  1.157448 1757.000000 289.100006
# 2021-10-02        NaN 47711.488281       NaN         NaN        NaN
# 2021-10-03        NaN 48199.953125       NaN         NaN        NaN
# 2021-10-04 223.789993 49112.902344  1.160726 1766.199951 283.109985
# 2021-10-05 224.419998 51514.812500  1.161845 1759.599976 288.760010
# ...               ...          ...       ...         ...        ...
# 2023-02-13 215.649994 21808.101562  1.067771 1851.900024 271.320007
# 2023-02-14 218.449997 22220.804688  1.073042 1854.000000 272.170013
# 2023-02-15 217.440002 24307.841797  1.073572 1834.199951 269.320007
# 2023-02-16 212.210007          NaN  1.069176 1842.000000 262.149994
# 2023-02-17 211.660004          NaN  1.066576 1851.300049 258.059998
#
#                    ^DJI  USDEUR=X
# Date
# 2021-10-01 34326.460938  0.863970
# 2021-10-02          NaN       NaN
# 2021-10-03          NaN       NaN
# 2021-10-04 34002.921875  0.861530
# 2021-10-05 34314.671875  0.860700
# ...                 ...       ...
# 2023-02-13 34245.929688  0.936530
# 2023-02-14 34089.269531  0.931930
# 2023-02-15 34128.050781  0.931470
# 2023-02-16 33696.851562  0.935300
# 2023-02-17 33826.691406  0.937580
#
# [505 rows x 7 columns]

# %%
fx = close[["EURUSD=X", "USDEUR=X"]].dropna().copy()

# %%
fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2021-10-01  1.157448  0.863970
# 2021-10-04  1.160726  0.861530
# 2021-10-05  1.161845  0.860700
# 2021-10-06  1.159608  0.862360
# 2021-10-07  1.155535  0.865400
# ...              ...       ...
# 2023-02-13  1.067771  0.936530
# 2023-02-14  1.073042  0.931930
# 2023-02-15  1.073572  0.931470
# 2023-02-16  1.069176  0.935300
# 2023-02-17  1.066576  0.937580
#
# [361 rows x 2 columns]

# %%
fx.plot(figsize = (12,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
simple_ret = fx.pct_change() # simple returns
simple_ret
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2021-10-01       NaN       NaN
# 2021-10-04  0.002832 -0.002824
# 2021-10-05  0.000964 -0.000963
# 2021-10-06 -0.001925  0.001929
# 2021-10-07 -0.003513  0.003525
# ...              ...       ...
# 2023-02-13 -0.006012  0.006048
# 2023-02-14  0.004936 -0.004912
# 2023-02-15  0.000494 -0.000494
# 2023-02-16 -0.004095  0.004112
# 2023-02-17 -0.002432  0.002438
#
# [361 rows x 2 columns]

# %%
simple_ret.add(1).prod() - 1 # compound simple returns
# Out:
# EURUSD=X   -0.078511
# USDEUR=X    0.085200
# dtype: float64

# %%
# -> For simple returns: long position returns != short position returns * (-1)

log_ret = np.log(fx / fx.shift()) # log returns
log_ret
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2021-10-01       NaN       NaN
# 2021-10-04  0.002828 -0.002828
# 2021-10-05  0.000964 -0.000964
# 2021-10-06 -0.001927  0.001927
# 2021-10-07 -0.003519  0.003519
# ...              ...       ...
# 2023-02-13 -0.006030  0.006030
# 2023-02-14  0.004924 -0.004924
# 2023-02-15  0.000494 -0.000494
# 2023-02-16 -0.004103  0.004103
# 2023-02-17 -0.002435  0.002435
#
# [361 rows x 2 columns]

# %%
log_ret.sum() # cumulative log returns
# Out:
# EURUSD=X   -0.081764
# USDEUR=X    0.081764
# dtype: float64

# %%
# -> For log returns: long position returns == short position returns * (-1)

norm_fx = log_ret.cumsum().apply(np.exp) # normalized prices (Base 1)
norm_fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2021-10-01       NaN       NaN
# 2021-10-04  1.002832  0.997176
# 2021-10-05  1.003799  0.996215
# 2021-10-06  1.001867  0.998137
# 2021-10-07  0.998348  1.001655
# ...              ...       ...
# 2023-02-13  0.922523  1.083984
# 2023-02-14  0.927076  1.078660
# 2023-02-15  0.927534  1.078128
# 2023-02-16  0.923736  1.082561
# 2023-02-17  0.921489  1.085200
#
# [361 rows x 2 columns]

# %%
norm_fx.iloc[0] = [1, 1]

# %%
norm_fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2021-10-01  1.000000  1.000000
# 2021-10-04  1.002832  0.997176
# 2021-10-05  1.003799  0.996215
# 2021-10-06  1.001867  0.998137
# 2021-10-07  0.998348  1.001655
# ...              ...       ...
# 2023-02-13  0.922523  1.083984
# 2023-02-14  0.927076  1.078660
# 2023-02-15  0.927534  1.078128
# 2023-02-16  0.923736  1.082561
# 2023-02-17  0.921489  1.085200
#
# [361 rows x 2 columns]

# %%
norm_fx.plot(figsize = (12,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# # Coding Challenge #6
#
# Calculate daily log returns for Boeing.
#
# Calculate the annualized mean and annualized std (assume 252 trading days per year) for a short position in Boeing (ignore Trading and Borrowing Costs).

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
ba = close["BA"].dropna().to_frame().copy()
ba
# Out:
#                  BA
# Date
# 2021-10-01 226.0000
# 2021-10-04 223.7900
# 2021-10-05 224.4200
# 2021-10-06 224.9900
# 2021-10-07 226.4800
# ...             ...
# 2023-02-13 215.6500
# 2023-02-14 218.4500
# 2023-02-15 217.4400
# 2023-02-16 212.2100
# 2023-02-17 211.6600
#
# [348 rows x 1 columns]

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba
# Out:
#                  BA  log_ret
# Date
# 2021-10-01 226.0000      NaN
# 2021-10-04 223.7900  -0.0098
# 2021-10-05 224.4200   0.0028
# 2021-10-06 224.9900   0.0025
# 2021-10-07 226.4800   0.0066
# ...             ...      ...
# 2023-02-13 215.6500   0.0129
# 2023-02-14 218.4500   0.0129
# 2023-02-15 217.4400  -0.0046
# 2023-02-16 212.2100  -0.0243
# 2023-02-17 211.6600  -0.0026
#
# [348 rows x 2 columns]

# %%
ba["short"] = ba.log_ret * (-1)
ba
# Out:
#                  BA  log_ret   short
# Date
# 2021-10-01 226.0000      NaN     NaN
# 2021-10-04 223.7900  -0.0098  0.0098
# 2021-10-05 224.4200   0.0028 -0.0028
# 2021-10-06 224.9900   0.0025 -0.0025
# 2021-10-07 226.4800   0.0066 -0.0066
# ...             ...      ...     ...
# 2023-02-13 215.6500   0.0129 -0.0129
# 2023-02-14 218.4500   0.0129 -0.0129
# 2023-02-15 217.4400  -0.0046  0.0046
# 2023-02-16 212.2100  -0.0243  0.0243
# 2023-02-17 211.6600  -0.0026  0.0026
#
# [348 rows x 3 columns]

# %%
ann_mean = ba.short.mean() * 252 # equal to ann_mean of long position * (-1)
ann_mean
# Out:
# 0.04760677121851414

# %%
ann_std = ba.short.std() * np.sqrt(252) # same as ann_std of long position
ann_std
# Out:
# 0.43733110232506683

# %% [markdown]
# # Covariance and Correlation
# Do instruments/assets move together (and to what extent)?
#
# Three cases:
#
# unrelated (no relationship/correlation)
# moving together (positive relationship/correlation)
# moving in opposite directions (negative relationship/correlation)
# -> Correlation between instruments/assets play an important role in portfolio management.

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
close["USDEUR=X"] = 1/close["EURUSD=X"]
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI  \
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
#             USDEUR=X
# Date
# 2021-10-01    0.8640
# 2021-10-02       NaN
# 2021-10-03       NaN
# 2021-10-04    0.8615
# 2021-10-05    0.8607
# ...              ...
# 2023-02-13    0.9365
# 2023-02-14    0.9319
# 2023-02-15    0.9315
# 2023-02-16    0.9353
# 2023-02-17    0.9376
#
# [505 rows x 7 columns]

# %%
returns = close.apply(lambda x: np.log(x.dropna() / x.dropna().shift()))
returns
# Out:
#                 BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# Date
# 2021-10-01     NaN      NaN       NaN     NaN     NaN     NaN       NaN
# 2021-10-02     NaN  -0.0085       NaN     NaN     NaN     NaN       NaN
# 2021-10-03     NaN   0.0102       NaN     NaN     NaN     NaN       NaN
# 2021-10-04 -0.0098   0.0188    0.0028  0.0052 -0.0209 -0.0095   -0.0028
# 2021-10-05  0.0028   0.0477    0.0010 -0.0037  0.0198  0.0091   -0.0010
# ...            ...      ...       ...     ...     ...     ...       ...
# 2023-02-13  0.0129   0.0009   -0.0060 -0.0059  0.0308  0.0111    0.0060
# 2023-02-14  0.0129   0.0187    0.0049  0.0011  0.0031 -0.0046   -0.0049
# 2023-02-15 -0.0046   0.0898    0.0005 -0.0107 -0.0105  0.0011   -0.0005
# 2023-02-16 -0.0243      NaN   -0.0041  0.0042 -0.0270 -0.0127    0.0041
# 2023-02-17 -0.0026      NaN   -0.0024  0.0050 -0.0157  0.0038    0.0024
#
# [505 rows x 7 columns]

# %%
returns.cov() # covariance (hard to interpret)
# Out:
#               BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# BA        0.0008   0.0003   -0.0000  0.0000  0.0002  0.0002    0.0000
# BTC-USD   0.0003   0.0011   -0.0000  0.0000  0.0004  0.0002    0.0000
# EURUSD=X -0.0000  -0.0000    0.0000  0.0000  0.0000 -0.0000   -0.0000
# GC=F      0.0000   0.0000    0.0000  0.0001  0.0000  0.0000   -0.0000
# MSFT      0.0002   0.0004    0.0000  0.0000  0.0004  0.0002   -0.0000
# ^DJI      0.0002   0.0002   -0.0000  0.0000  0.0002  0.0001    0.0000
# USDEUR=X  0.0000   0.0000   -0.0000 -0.0000 -0.0000  0.0000    0.0000

# %%
returns.corr() # correlation coefficient (easy to interpret)
# Out:
#               BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# BA        1.0000   0.3286   -0.0313  0.1137  0.4275  0.6246    0.0313
# BTC-USD   0.3286   1.0000   -0.0117  0.0884  0.4797  0.4734    0.0117
# EURUSD=X -0.0313  -0.0117    1.0000  0.0688  0.0132 -0.0334   -1.0000
# GC=F      0.1137   0.0884    0.0688  1.0000  0.0503  0.0788   -0.0688
# MSFT      0.4275   0.4797    0.0132  0.0503  1.0000  0.7636   -0.0132
# ^DJI      0.6246   0.4734   -0.0334  0.0788  0.7636  1.0000    0.0334
# USDEUR=X  0.0313   0.0117   -1.0000 -0.0688 -0.0132  0.0334    1.0000

# %%
# Three cases:

#   * no correlation: correlation coefficient == 0
#   * moving together: 0 < correlation coefficient <= 1 (positive)
#   *moving in opposite directions: -1 <= correlation coefficient < 0 (negative)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(returns.corr(), cmap = "RdYlBu_r", annot = True, annot_kws={"size":15}, vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# Take Home: Similar assets are (highly) positive correlated. Different assets exhibit low/no/negative correlation.
# -> In portfolio management it´s beneficial to have assets with low/no/negative correlation (portfolio diversification effect).

# %% [markdown]
# # Portfolio of Assets and Portfolio Returns

# %%
import pandas as pd
import numpy as np

# %%
prices = pd.DataFrame(data = {"Asset_A": [100, 112], "Asset_B":[100, 104]}, index = [0, 1])
prices
# Out:
#    Asset_A  Asset_B
# 0      100      100
# 1      112      104

# %%
prices["Total"] = prices.Asset_A + prices.Asset_B

# %%
prices
# Out:
#    Asset_A  Asset_B  Total
# 0      100      100    200
# 1      112      104    216

# %%
returns = prices.pct_change() # simple returns
returns
# Out:
#    Asset_A  Asset_B  Total
# 0      NaN      NaN    NaN
# 1   0.1200   0.0400 0.0800

# %%
0.5 * 0.12 + 0.5 * 0.04 # correct (portfolio return == weighted average of simple returns)
# Out:
# 0.08

# %%
log_returns = np.log(prices / prices.shift()) # log returns
log_returns
# Out:
#    Asset_A  Asset_B  Total
# 0      NaN      NaN    NaN
# 1   0.1133   0.0392 0.0770

# %%
0.5 * log_returns.iloc[1,0] + 0.5 * log_returns.iloc[1,1] # incorrect (portfolio return != weighted average of log returns)
# Out:
# 0.0762746992301423

# %% [markdown]
# Take Home: While log returns are time-additive, they are not asset-additive.
# (While simple returns are not time-additive, they are asset-additive.)

# %% [markdown]
# # Margin Trading & Levered Returns (Part 1)
# Definition: "Margin trading refers to the practice of using borrowed funds from a broker to trade a financial asset, which forms the collateral for the loan from the broker." (Investopedia.com)
#
# In Simple Words: Investors don´t pay the full price but they get the full benefit (less borrowing costs).
#
# It´s a two edged sword: Leverage amplifies both gains and losses.
# In the event of a loss, the collateral gets reduced and the Investor either posts additional margin or the brokers closes the position.
#
# Example
#
# A Trader buys a stock (stock price: 100) on margin (50%). After one day the price increases to 110.
# Calculate unlevered return and levered return.

# %%
P0 = 100
P1 = 110
leverage = 2
margin = P0/2

# %%
margin
# Out:
# 50.0

# %%
unlev_return = (P1 - P0) / P0 # simple return
unlev_return
# Out:
# 0.1

# %%
lev_return == unlev_return * leverage # this relationship is true for simple returns...

# %%
unlev_return = np.log((P1 - P0) / P0 + 1) # log return
unlev_return
# Out:
# 0.09531017980432493

# %%
lev_return = np.log((P1 - P0) / margin + 1) # log return
lev_return
# Out:
# 0.1823215567939546

# %%
lev_return == unlev_return * leverage # this relationship does not hold for log returns...
# Out:
# False

# %% [markdown]
# Take Home: To calculate levered returns, don´t multiply leverage with log returns!

# %% [markdown]
# # Margin Trading & Levered Returns (Part 2)
# Hypothesis: For (highly) profitable Investment: The more leverage, the better?

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2021-10-01 289.1000      NaN
# 2021-10-04 283.1100  -0.0207
# 2021-10-05 288.7600   0.0200
# 2021-10-06 293.1100   0.0151
# 2021-10-07 294.8500   0.0059
# ...             ...      ...
# 2023-02-13 271.3200   0.0312
# 2023-02-14 272.1700   0.0031
# 2023-02-15 269.3200  -0.0105
# 2023-02-16 262.1500  -0.0266
# 2023-02-17 258.0600  -0.0156
#
# [348 rows x 2 columns]

# %%
msft["Simple_Ret"] = msft.Price.pct_change() # simple returns

# %%
leverage = 2

# %%
# (Simplified) Assumptions:

#   * Restore leverage on a daily basis (by buying/selling shares)
#   * no trading costs
#   * no borrowing costs

# %%
msft["Lev_Returns"] = msft.Returns.mul(leverage) # levered simple returns
msft
# Out:
#               Price  Returns  Simple_Ret  Lev_Returns
# Date
# 2021-10-01 289.1000      NaN         NaN          NaN
# 2021-10-04 283.1100  -0.0207     -0.0207      -0.0414
# 2021-10-05 288.7600   0.0200      0.0200       0.0399
# 2021-10-06 293.1100   0.0151      0.0151       0.0301
# 2021-10-07 294.8500   0.0059      0.0059       0.0119
# ...             ...      ...         ...          ...
# 2023-02-13 271.3200   0.0312      0.0312       0.0625
# 2023-02-14 272.1700   0.0031      0.0031       0.0063
# 2023-02-15 269.3200  -0.0105     -0.0105      -0.0209
# 2023-02-16 262.1500  -0.0266     -0.0266      -0.0532
# 2023-02-17 258.0600  -0.0156     -0.0156      -0.0312
#
# [348 rows x 4 columns]

# %%
msft["Lev_Returns"] = np.where(msft["Lev_Returns"] < -1, -1, msft["Lev_Returns"])

# %%
msft
# Out:
#               Price  Returns  Simple_Ret  Lev_Returns
# Date
# 2021-10-01 289.1000      NaN         NaN          NaN
# 2021-10-04 283.1100  -0.0207     -0.0207      -0.0414
# 2021-10-05 288.7600   0.0200      0.0200       0.0399
# 2021-10-06 293.1100   0.0151      0.0151       0.0301
# 2021-10-07 294.8500   0.0059      0.0059       0.0119
# ...             ...      ...         ...          ...
# 2023-02-13 271.3200   0.0312      0.0312       0.0625
# 2023-02-14 272.1700   0.0031      0.0031       0.0063
# 2023-02-15 269.3200  -0.0105     -0.0105      -0.0209
# 2023-02-16 262.1500  -0.0266     -0.0266      -0.0532
# 2023-02-17 258.0600  -0.0156     -0.0156      -0.0312
#
# [348 rows x 4 columns]

# %%
msft[["Returns", "Lev_Returns"]].add(1).cumprod().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
msft.Simple_Ret.max()
# Out:
# 0.08226805787098557

# %%
msft.Lev_Returns.max()
# Out:
# 0.164536115741971

# %%
msft.Simple_Ret.min()
# Out:
# -0.07715629161148874

# %%
msft.Lev_Returns.min()
# Out:
# -0.1543125832229776

# %%
# What happens when leverage greater than...?

-1 / msft.Simple_Ret.min()
# Out:
# 12.960705849308832

# %%
# Take Home:

#   1.With Leverage you can (theoretically) lose more than the initial Margin (in practice: margin call / margin closeout before)
#   2.Even for (highly) profitable instruments: "The more leverage the better" does not hold.
#   3.It´s a two edged (non-symmetrical) sword: Leverage amplifies losses more than it amplifies gains.

# %% [markdown]
# # Coding Challenge #7

# %%
# Coding Challenge #7

#   1.Calculate levered returns for Bitcoin (leverage = 4).

#   2.Visualize and compare with unlevered Investment.

#   3.Some Traders trade Bitcoin with extremely high leverage (> 100).
#   Do you think this is a good idea (assuming no additional/advanced Risk Management Tools)?

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2021-10-01 226.0000 48116.9414    1.1574 1757.0000 289.1000 34326.4609
# 2021-10-02      NaN 47711.4883       NaN       NaN      NaN        NaN
# 2021-10-03      NaN 48199.9531       NaN       NaN      NaN        NaN
# 2021-10-04 223.7900 49112.9023    1.1607 1766.2000 283.1100 34002.9219
# 2021-10-05 224.4200 51514.8125    1.1618 1759.6000 288.7600 34314.6719
# ...             ...        ...       ...       ...      ...        ...
# 2023-02-13 215.6500 21808.1016    1.0678 1851.9000 271.3200 34245.9297
# 2023-02-14 218.4500 22220.8047    1.0730 1854.0000 272.1700 34089.2695
# 2023-02-15 217.4400 24307.8418    1.0736 1834.2000 269.3200 34128.0508
# 2023-02-16 212.2100        NaN    1.0692 1842.0000 262.1500 33696.8516
# 2023-02-17 211.6600        NaN    1.0666 1851.3000 258.0600 33826.6914
#
# [505 rows x 6 columns]

# %%
btc = close["BTC-USD"].dropna().to_frame().copy()
btc
# Out:
#               BTC-USD
# Date
# 2021-10-01 48116.9414
# 2021-10-02 47711.4883
# 2021-10-03 48199.9531
# 2021-10-04 49112.9023
# 2021-10-05 51514.8125
# ...               ...
# 2023-02-11 21870.8750
# 2023-02-12 21788.2031
# 2023-02-13 21808.1016
# 2023-02-14 22220.8047
# 2023-02-15 24307.8418
#
# [503 rows x 1 columns]

# %%
btc["Returns"] = btc.pct_change(periods = 1)
btc
# Out:
#               BTC-USD  Returns
# Date
# 2021-10-01 48116.9414      NaN
# 2021-10-02 47711.4883  -0.0084
# 2021-10-03 48199.9531   0.0102
# 2021-10-04 49112.9023   0.0189
# 2021-10-05 51514.8125   0.0489
# ...               ...      ...
# 2023-02-11 21870.8750   0.0101
# 2023-02-12 21788.2031  -0.0038
# 2023-02-13 21808.1016   0.0009
# 2023-02-14 22220.8047   0.0189
# 2023-02-15 24307.8418   0.0939
#
# [503 rows x 2 columns]

# %%
leverage = 4

# %%
btc["Lev_Returns"] = btc.Returns.mul(leverage) # levered simple returns
btc
# Out:
#               BTC-USD  Returns  Lev_Returns
# Date
# 2021-10-01 48116.9414      NaN          NaN
# 2021-10-02 47711.4883  -0.0084      -0.0337
# 2021-10-03 48199.9531   0.0102       0.0410
# 2021-10-04 49112.9023   0.0189       0.0758
# 2021-10-05 51514.8125   0.0489       0.1956
# ...               ...      ...          ...
# 2023-02-11 21870.8750   0.0101       0.0406
# 2023-02-12 21788.2031  -0.0038      -0.0151
# 2023-02-13 21808.1016   0.0009       0.0037
# 2023-02-14 22220.8047   0.0189       0.0757
# 2023-02-15 24307.8418   0.0939       0.3757
#
# [503 rows x 3 columns]

# %%
btc["Lev_Returns"] = np.where(btc["Lev_Returns"] < -1, -1, btc["Lev_Returns"])

# %%
btc[["Returns", "Lev_Returns"]].add(1).cumprod().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# -> Trading Bitcoin with (high) leverage requires advanced risk monitoring/management. Otherwise, a complete loss is very likely (sooner or later...).
